# %%
# !pip install gdown
# Out:
# Requirement already satisfied: gdown in /usr/local/lib/python3.10/dist-packages (5.1.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from gdown) (4.12.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from gdown) (3.15.4)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.10/dist-packages (from gdown) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from gdown) (4.66.5)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->gdown) (2.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (2024.7.4)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (1.7.1)

# %%
# !gdown https://drive.google.com/file/d/1c-J0AlAVMKVYtriwlxqkbx94gafAQLjB/view?usp=sharing --fuzzy
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1c-J0AlAVMKVYtriwlxqkbx94gafAQLjB
# From (redirected): https://drive.google.com/uc?id=1c-J0AlAVMKVYtriwlxqkbx94gafAQLjB&confirm=t&uuid=8f3aed9e-34d7-48e4-b85a-876476283d45
# To: /content/driver_161_90frame.tar.gz
# 100% 5.04G/5.04G [01:03<00:00, 79.0MB/s]

# %%
# !tar -xvzf driver_161_90frame.tar.gz
# Out:
# Streaming output truncated to the last 5000 lines.
# driver_161_90frame/06032332_0990.MP4/02880.lines.txt
# driver_161_90frame/06040114_1024.MP4/02700.jpg
# driver_161_90frame/06040111_1023.MP4/02070.lines.txt
# driver_161_90frame/06032113_0944.MP4/02700.lines.txt
# driver_161_90frame/06040214_1044.MP4/01440.jpg
# driver_161_90frame/06040314_1064.MP4/00180.jpg
# driver_161_90frame/06031608_0865.MP4/00090.jpg
# driver_161_90frame/06031625_0871.MP4/01620.jpg
# driver_161_90frame/06031152_0826.MP4/00990.jpg
# driver_161_90frame/06031725_0891.MP4/00360.jpg
# driver_161_90frame/06032252_0977.MP4/02430.jpg
# driver_161_90frame/06032231_0970.MP4/03060.jpg
# driver_161_90frame/06040053_1017.MP4/03240.jpg
# driver_161_90frame/06032329_0989.MP4/03870.lines.txt
# driver_161_90frame/06030819_0755.MP4/05310.lines.txt
# driver_161_90frame/06031743_0897.MP4/00900.lines.txt
# driver_161_90frame/06031323_0849.MP4/02880.jpg
# driver_161_90frame/06031819_0909.MP4/02610.lines.txt
# driver_161_90frame/06031228_0838.MP4/02250.lines.txt
# driver_161_90frame/06032344_0994.MP4/00540.jpg
# driver_161_90frame/06031704_0884.MP4/01170.jpg
# driver_161_90frame/06031556_0861.MP4/01530.jpg
# driver_161_90frame/06032110_0943.MP4/05130.jpg
# driver_161_90frame/06040202_1040.MP4/02790.lines.txt
# driver_161_90frame/06032255_0978.MP4/03510.lines.txt
# driver_161_90frame/06032146_0955.MP4/02340.lines.txt
# driver_161_90frame/06031049_0805.MP4/01440.jpg
# driver_161_90frame/06031643_0877.MP4/04230.lines.txt
# driver_161_90frame/06031022_0796.MP4/01710.lines.txt
# driver_161_90frame/06031149_0825.MP4/00180.jpg
# driver_161_90frame/06030843_0763.MP4/02520.lines.txt
# driver_161_90frame/06030910_0772.MP4/05130.jpg
# driver_161_90frame/06040241_1053.MP4/02430.jpg
# driver_161_90frame/06031535_0854.MP4/02340.jpg
# driver_161_90frame/06030931_0779.MP4/04500.jpg
# driver_161_90frame/06031913_0927.MP4/03420.lines.txt
# driver_161_90frame/06040105_1021.MP4/03330.jpg
# driver_161_90frame/06031652_0880.MP4/02610.jpg
# driver_161_90frame/06031210_0832.MP4/03870.lines.txt
# driver_161_90frame/06032304_0981.MP4/02520.jpg
# driver_161_90frame/06040205_1041.MP4/02070.jpg
# driver_161_90frame/06040108_1022.MP4/02610.lines.txt
# driver_161_90frame/06040120_1026.MP4/04500.jpg
# driver_161_90frame/06032055_0938.MP4/00810.jpg
# driver_161_90frame/06040226_1048.MP4/01440.jpg
# driver_161_90frame/06031631_0873.MP4/03420.jpg
# driver_161_90frame/06031731_0893.MP4/02160.jpg
# driver_161_90frame/06031737_0895.MP4/00360.jpg
# driver_161_90frame/06031734_0894.MP4/04950.lines.txt
# driver_161_90frame/06031028_0798.MP4/04050.jpg
# driver_161_90frame/06031610_0866.MP4/04230.jpg
# driver_161_90frame/06031616_0868.MP4/02430.jpg
# driver_161_90frame/06030819_0755.MP4/00450.jpg
# driver_161_90frame/06040223_1047.MP4/00990.lines.txt
# driver_161_90frame/06032335_0991.MP4/01170.jpg
# driver_161_90frame/06031608_0865.MP4/01800.jpg
# driver_161_90frame/06031707_0885.MP4/00810.lines.txt
# driver_161_90frame/06040141_1033.MP4/04320.lines.txt
# driver_161_90frame/06030943_0783.MP4/04320.jpg
# driver_161_90frame/06032356_0998.MP4/00540.jpg
# driver_161_90frame/06032110_0943.MP4/04320.lines.txt
# driver_161_90frame/06032107_0942.MP4/00900.jpg
# driver_161_90frame/06030831_0759.MP4/00090.lines.txt
# driver_161_90frame/06040032_1010.MP4/03150.lines.txt
# driver_161_90frame/06031834_0914.MP4/03870.lines.txt
# driver_161_90frame/06030916_0774.MP4/03600.lines.txt
# driver_161_90frame/06040132_1030.MP4/04320.jpg
# driver_161_90frame/06031055_0807.MP4/03240.jpg
# driver_161_90frame/06040232_1050.MP4/03060.jpg
# driver_161_90frame/06031210_0832.MP4/02880.jpg
# driver_161_90frame/06030922_0776.MP4/05130.jpg
# driver_161_90frame/06040253_1057.MP4/02430.jpg
# driver_161_90frame/06031547_0858.MP4/02340.jpg
# driver_161_90frame/06031541_0856.MP4/04140.jpg
# driver_161_90frame/06031740_0896.MP4/02520.lines.txt
# driver_161_90frame/06040111_1023.MP4/05130.jpg
# driver_161_90frame/06032046_0935.MP4/01440.jpg
# driver_161_90frame/06030940_0782.MP4/00810.lines.txt
# driver_161_90frame/06032310_0983.MP4/04320.jpg
# driver_161_90frame/06032146_0955.MP4/00180.jpg
# driver_161_90frame/06031631_0873.MP4/01350.lines.txt
# driver_161_90frame/06031249_0845.MP4/00630.jpg
# driver_161_90frame/06031622_0870.MP4/04050.jpg
# driver_161_90frame/06032313_0984.MP4/04230.lines.txt
# driver_161_90frame/06031643_0877.MP4/03420.jpg
# driver_161_90frame/06031107_0811.MP4/03330.jpg
# driver_161_90frame/06040205_1041.MP4/00900.lines.txt
# driver_161_90frame/06030840_0762.MP4/04140.lines.txt
# driver_161_90frame/06031743_0897.MP4/02160.jpg
# driver_161_90frame/06030949_0785.MP4/03240.lines.txt
# driver_161_90frame/06031128_0818.MP4/02700.jpg
# driver_161_90frame/06040305_1061.MP4/02520.jpg
# driver_161_90frame/06031901_0923.MP4/00540.lines.txt
# driver_161_90frame/06032158_0959.MP4/04590.lines.txt
# driver_161_90frame/06031910_0926.MP4/05040.lines.txt
# driver_161_90frame/06040105_1021.MP4/04230.lines.txt
# driver_161_90frame/06032119_0946.MP4/00900.jpg
# driver_161_90frame/06031755_0901.MP4/00180.jpg
# driver_161_90frame/06030828_0758.MP4/00630.lines.txt
# driver_161_90frame/06040244_1054.MP4/03060.jpg
# driver_161_90frame/06031104_0810.MP4/00810.lines.txt
# driver_161_90frame/06030919_0775.MP4/00900.jpg
# driver_161_90frame/06040150_1036.MP4/00990.jpg
# driver_161_90frame/06031610_0866.MP4/03960.lines.txt
# driver_161_90frame/06031113_0813.MP4/05310.lines.txt
# driver_161_90frame/06040238_1052.MP4/00540.lines.txt
# driver_161_90frame/06040123_1027.MP4/05130.jpg
# driver_161_90frame/06032052_0937.MP4/03240.jpg
# driver_161_90frame/06032158_0959.MP4/00180.jpg
# driver_161_90frame/06031201_0829.MP4/03690.jpg
# driver_161_90frame/06030837_0761.MP4/02070.jpg
# driver_161_90frame/06040308_1062.MP4/04140.lines.txt
# driver_161_90frame/06031219_0835.MP4/02070.jpg
# driver_161_90frame/06032104_0941.MP4/03330.jpg
# driver_161_90frame/06031755_0901.MP4/04950.lines.txt
# driver_161_90frame/06030858_0768.MP4/01440.jpg
# driver_161_90frame/06032350_0996.MP4/03330.lines.txt
# driver_161_90frame/06031822_0910.MP4/01440.jpg
# driver_161_90frame/06031119_0815.MP4/03330.jpg
# driver_161_90frame/06030958_0788.MP4/00180.jpg
# driver_161_90frame/06031843_0917.MP4/00810.jpg
# driver_161_90frame/06031605_0864.MP4/04230.jpg
# driver_161_90frame/06031246_0844.MP4/01620.lines.txt
# driver_161_90frame/06040126_1028.MP4/02430.lines.txt
# driver_161_90frame/06040047_1015.MP4/01440.jpg
# driver_161_90frame/06040311_1063.MP4/04320.jpg
# driver_161_90frame/06032246_0975.MP4/00630.jpg
# driver_161_90frame/06040147_1035.MP4/00180.jpg
# driver_161_90frame/06031722_0890.MP4/04500.jpg
# driver_161_90frame/06031137_0821.MP4/00450.lines.txt
# driver_161_90frame/06030819_0755.MP4/04680.lines.txt
# driver_161_90frame/06031807_0905.MP4/00450.jpg
# driver_161_90frame/06031819_0909.MP4/01980.lines.txt
# driver_161_90frame/06031801_0903.MP4/02250.jpg
# driver_161_90frame/06032301_0980.MP4/01350.lines.txt
# driver_161_90frame/06031004_0790.MP4/03690.jpg
# driver_161_90frame/06032255_0978.MP4/02880.lines.txt
# driver_161_90frame/06032125_0948.MP4/02700.jpg
# driver_161_90frame/06040026_1008.MP4/02250.jpg
# driver_161_90frame/06040144_1034.MP4/
# driver_161_90frame/06032225_0968.MP4/01440.jpg
# driver_161_90frame/06032234_0971.MP4/05310.lines.txt
# driver_161_90frame/06031701_0883.MP4/05310.jpg
# driver_161_90frame/06030843_0763.MP4/01890.lines.txt
# driver_161_90frame/06031608_0865.MP4/03150.lines.txt
# driver_161_90frame/06031146_0824.MP4/04320.jpg
# driver_161_90frame/06031822_0910.MP4/01620.lines.txt
# driver_161_90frame/06031855_0921.MP4/00630.jpg
# driver_161_90frame/06032052_0937.MP4/03600.lines.txt
# driver_161_90frame/06040108_1022.MP4/01980.lines.txt
# driver_161_90frame/06031913_0927.MP4/02790.lines.txt
# driver_161_90frame/06040159_1039.MP4/02070.lines.txt
# driver_161_90frame/06031246_0844.MP4/03060.jpg
# driver_161_90frame/06030849_0765.MP4/02070.jpg
# driver_161_90frame/06032128_0949.MP4/02070.lines.txt
# driver_161_90frame/06030825_0757.MP4/02250.lines.txt
# driver_161_90frame/06040038_1012.MP4/02070.jpg
# driver_161_90frame/06031055_0807.MP4/03960.lines.txt
# driver_161_90frame/06031125_0817.MP4/05130.jpg
# driver_161_90frame/06032137_0952.MP4/02520.jpg
# driver_161_90frame/06031834_0914.MP4/01440.jpg
# driver_161_90frame/06032131_0950.MP4/04320.jpg
# driver_161_90frame/06032237_0972.MP4/01260.jpg
# driver_161_90frame/06032216_0965.MP4/02070.jpg
# driver_161_90frame/06040059_1019.MP4/01440.jpg
# driver_161_90frame/06040311_1063.MP4/03960.lines.txt
# driver_161_90frame/06032258_0979.MP4/00630.jpg
# driver_161_90frame/06040159_1039.MP4/00180.jpg
# driver_161_90frame/06030937_0781.MP4/02520.jpg
# driver_161_90frame/06040141_1033.MP4/03690.lines.txt
# driver_161_90frame/06031813_0907.MP4/02250.jpg
# driver_161_90frame/06032116_0945.MP4/03330.jpg
# driver_161_90frame/06032332_0990.MP4/05310.jpg
# driver_161_90frame/06031625_0871.MP4/03510.lines.txt
# driver_161_90frame/06032110_0943.MP4/03690.lines.txt
# driver_161_90frame/06031016_0794.MP4/03690.jpg
# driver_161_90frame/06031855_0921.MP4/01260.lines.txt
# driver_161_90frame/06040229_1049.MP4/
# driver_161_90frame/06030916_0774.MP4/02970.lines.txt
# driver_161_90frame/06031031_0799.MP4/04860.jpg
# driver_161_90frame/06030916_0774.MP4/03330.jpg
# driver_161_90frame/06040247_1055.MP4/00630.jpg
# driver_161_90frame/06031158_0828.MP4/04320.jpg
# driver_161_90frame/06031907_0925.MP4/00900.jpg
# driver_161_90frame/06031901_0923.MP4/02700.jpg
# driver_161_90frame/06031658_0882.MP4/00810.jpg
# driver_161_90frame/06040047_1015.MP4/03510.lines.txt
# driver_161_90frame/06031134_0820.MP4/02070.lines.txt
# driver_161_90frame/06031740_0896.MP4/01890.lines.txt
# driver_161_90frame/06040126_1028.MP4/02700.jpg
# driver_161_90frame/06031043_0803.MP4/02880.jpg
# driver_161_90frame/06031122_0816.MP4/00630.lines.txt
# driver_161_90frame/06032143_0954.MP4/04320.jpg
# driver_161_90frame/06031637_0875.MP4/01620.jpg
# driver_161_90frame/06031131_0819.MP4/05130.lines.txt
# driver_161_90frame/06031658_0882.MP4/03150.lines.txt
# driver_161_90frame/06031840_0916.MP4/03240.jpg
# driver_161_90frame/06031916_0928.MP4/00900.lines.txt
# driver_161_90frame/06032243_0974.MP4/03060.jpg
# driver_161_90frame/06031646_0878.MP4/01710.lines.txt
# driver_161_90frame/06040220_1046.MP4/02880.jpg
# driver_161_90frame/06031529_0852.MP4/04230.lines.txt
# driver_161_90frame/06030949_0785.MP4/02520.jpg
# driver_161_90frame/06032228_0969.MP4/02070.jpg
# driver_161_90frame/06031928_0932.MP4/02340.lines.txt
# driver_161_90frame/06032122_0947.MP4/05130.jpg
# driver_161_90frame/06031816_0908.MP4/04230.lines.txt
# driver_161_90frame/06030855_0767.MP4/04500.lines.txt
# driver_161_90frame/06032219_0966.MP4/03420.lines.txt
# driver_161_90frame/06040138_1032.MP4/02520.jpg
# driver_161_90frame/06031610_0866.MP4/03870.jpg
# driver_161_90frame/06031553_0860.MP4/01440.lines.txt
# driver_161_90frame/06040002_1000.MP4/01890.jpg
# driver_161_90frame/06040238_1052.MP4/01260.jpg
# driver_161_90frame/06032049_0936.MP4/03150.lines.txt
# driver_161_90frame/06030928_0778.MP4/03330.jpg
# driver_161_90frame/06031155_0827.MP4/00270.lines.txt
# driver_161_90frame/06040259_1059.MP4/00630.jpg
# driver_161_90frame/06040117_1025.MP4/03330.jpg
# driver_161_90frame/06031019_0795.MP4/01260.lines.txt
# driver_161_90frame/06031326_0850.MP4/00000.lines.txt
# driver_161_90frame/06032350_0996.MP4/01980.jpg
# driver_161_90frame/06031913_0927.MP4/02700.jpg
# driver_161_90frame/06031852_0920.MP4/03060.jpg
# driver_161_90frame/06031113_0813.MP4/04680.lines.txt
# driver_161_90frame/06032316_0985.MP4/02520.jpg
# driver_161_90frame/06032243_0974.MP4/00630.lines.txt
# driver_161_90frame/06040217_1045.MP4/02070.jpg
# driver_161_90frame/06031550_0859.MP4/04500.lines.txt
# driver_161_90frame/06032252_0977.MP4/05130.lines.txt
# driver_161_90frame/06031628_0872.MP4/02250.jpg
# driver_161_90frame/06031649_0879.MP4/01620.jpg
# driver_161_90frame/06040144_1034.MP4/01800.lines.txt
# driver_161_90frame/06031541_0856.MP4/03780.jpg
# driver_161_90frame/06031749_0899.MP4/00360.jpg
# driver_161_90frame/06032155_0958.MP4/04320.jpg
# driver_161_90frame/06031840_0916.MP4/01440.lines.txt
# driver_161_90frame/06040035_1011.MP4/00630.lines.txt
# driver_161_90frame/06032255_0978.MP4/03060.jpg
# driver_161_90frame/06031246_0844.MP4/00990.lines.txt
# driver_161_90frame/06032347_0995.MP4/01170.jpg
# driver_161_90frame/06040044_1014.MP4/05130.lines.txt
# driver_161_90frame/06031559_0862.MP4/02160.jpg
# driver_161_90frame/06030955_0787.MP4/04320.jpg
# driver_161_90frame/06031907_0925.MP4/04950.lines.txt
# driver_161_90frame/06030840_0762.MP4/02880.jpg
# driver_161_90frame/06031107_0811.MP4/02970.jpg
# driver_161_90frame/06031101_0809.MP4/04950.jpg
# driver_161_90frame/06032307_0982.MP4/03150.jpg
# driver_161_90frame/06040144_1034.MP4/04320.jpg
# driver_161_90frame/06031043_0803.MP4/01710.lines.txt
# driver_161_90frame/06040008_1002.MP4/05220.jpg
# driver_161_90frame/06031655_0881.MP4/03240.jpg
# driver_161_90frame/06031222_0836.MP4/02880.jpg
# driver_161_90frame/06032207_0962.MP4/04410.jpg
# driver_161_90frame/06032234_0971.MP4/04680.lines.txt
# driver_161_90frame/06030825_0757.MP4/01890.jpg
# driver_161_90frame/06031904_0924.MP4/03330.jpg
# driver_161_90frame/06031119_0815.MP4/00180.lines.txt
# driver_161_90frame/06032052_0937.MP4/02970.lines.txt
# driver_161_90frame/06032316_0985.MP4/01710.lines.txt
# driver_161_90frame/06031822_0910.MP4/00990.lines.txt
# driver_161_90frame/06032058_0939.MP4/01440.jpg
# driver_161_90frame/06040129_1029.MP4/03330.jpg
# driver_161_90frame/06040014_1004.MP4/01890.jpg
# driver_161_90frame/06031704_0884.MP4/02430.lines.txt
# driver_161_90frame/06040229_1049.MP4/02070.jpg
# driver_161_90frame/06032322_0987.MP4/04320.jpg
# driver_161_90frame/06032207_0962.MP4/00540.lines.txt
# driver_161_90frame/06030904_0770.MP4/00720.lines.txt
# driver_161_90frame/06040247_1055.MP4/05040.lines.txt
# driver_161_90frame/06031634_0874.MP4/04050.jpg
# driver_161_90frame/06032216_0965.MP4/05040.lines.txt
# driver_161_90frame/06030913_0773.MP4/05220.lines.txt
# driver_161_90frame/06031134_0820.MP4/03960.jpg
# driver_161_90frame/06031804_0904.MP4/01350.lines.txt
# driver_161_90frame/06031619_0869.MP4/03060.jpg
# driver_161_90frame/06032359_0999.MP4/01170.jpg
# driver_161_90frame/06031728_0892.MP4/02700.jpg
# driver_161_90frame/06032240_0973.MP4/02250.lines.txt
# driver_161_90frame/06031625_0871.MP4/02880.lines.txt
# driver_161_90frame/06030852_0766.MP4/02880.jpg
# driver_161_90frame/06031931_0933.MP4/04320.jpg
# driver_161_90frame/06031113_0813.MP4/04770.jpg
# driver_161_90frame/06032329_0989.MP4/03600.lines.txt
# driver_161_90frame/06032131_0950.MP4/01080.lines.txt
# driver_161_90frame/06031737_0895.MP4/02070.lines.txt
# driver_161_90frame/06040156_1038.MP4/04320.jpg
# driver_161_90frame/06040256_1058.MP4/03060.jpg
# driver_161_90frame/06040041_1013.MP4/02880.jpg
# driver_161_90frame/06030937_0781.MP4/00360.lines.txt
# driver_161_90frame/06040202_1040.MP4/02520.lines.txt
# driver_161_90frame/06031547_0858.MP4/04050.lines.txt
# driver_161_90frame/06030831_0759.MP4/03690.jpg
# driver_161_90frame/06032049_0936.MP4/02070.jpg
# driver_161_90frame/06031910_0926.MP4/05130.jpg
# driver_161_90frame/06031801_0903.MP4/01890.jpg
# driver_161_90frame/06040020_1006.MP4/03690.jpg
# driver_161_90frame/06031113_0813.MP4/00000.jpg
# driver_161_90frame/06032353_0997.MP4/00810.lines.txt
# driver_161_90frame/06040020_1006.MP4/00810.lines.txt
# driver_161_90frame/06040026_1008.MP4/01890.jpg
# driver_161_90frame/06040047_1015.MP4/02880.lines.txt
# driver_161_90frame/06030904_0770.MP4/02970.jpg
# driver_161_90frame/06031210_0832.MP4/03600.lines.txt
# driver_161_90frame/06031646_0878.MP4/04050.jpg
# driver_161_90frame/06040208_1042.MP4/04410.jpg
# driver_161_90frame/06031040_0802.MP4/03330.lines.txt
# driver_161_90frame/06040308_1062.MP4/03150.jpg
# driver_161_90frame/06031149_0825.MP4/02430.lines.txt
# driver_161_90frame/06040029_1009.MP4/03240.lines.txt
# driver_161_90frame/06040250_1056.MP4/04860.lines.txt
# driver_161_90frame/06040235_1051.MP4/02160.lines.txt
# driver_161_90frame/06031701_0883.MP4/04050.lines.txt
# driver_161_90frame/06031734_0894.MP4/04500.jpg
# driver_161_90frame/06031317_0847.MP4/04860.lines.txt
# driver_161_90frame/06031819_0909.MP4/00450.jpg
# driver_161_90frame/06040223_1047.MP4/00720.lines.txt
# driver_161_90frame/06032131_0950.MP4/03960.jpg
# driver_161_90frame/06032338_0992.MP4/03510.jpg
# driver_161_90frame/06030855_0767.MP4/03870.lines.txt
# driver_161_90frame/06040053_1017.MP4/00450.lines.txt
# driver_161_90frame/06032219_0966.MP4/02790.lines.txt
# driver_161_90frame/06040053_1017.MP4/02880.jpg
# driver_161_90frame/06040011_1003.MP4/04860.lines.txt
# driver_161_90frame/06032344_0994.MP4/04860.lines.txt
# driver_161_90frame/06031834_0914.MP4/03600.lines.txt
# driver_161_90frame/06031243_0843.MP4/03240.lines.txt
# driver_161_90frame/06040123_1027.MP4/04050.lines.txt
# driver_161_90frame/06032110_0943.MP4/04770.jpg
# driver_161_90frame/06031231_0839.MP4/01800.lines.txt
# driver_161_90frame/06031529_0852.MP4/05310.jpg
# driver_161_90frame/06031535_0854.MP4/01980.jpg
# driver_161_90frame/06031550_0859.MP4/03870.lines.txt
# driver_161_90frame/06031535_0854.MP4/01170.lines.txt
# driver_161_90frame/06032149_0956.MP4/02520.jpg
# driver_161_90frame/06030916_0774.MP4/02970.jpg
# driver_161_90frame/06030910_0772.MP4/04770.jpg
# driver_161_90frame/06031825_0911.MP4/02070.jpg
# driver_161_90frame/06031323_0849.MP4/02430.lines.txt
# driver_161_90frame/06032110_0943.MP4/00000.jpg
# driver_161_90frame/06040105_1021.MP4/02970.jpg
# driver_161_90frame/06031846_0918.MP4/01440.jpg
# driver_161_90frame/06040256_1058.MP4/00360.lines.txt
# driver_161_90frame/06031725_0891.MP4/05130.jpg
# driver_161_90frame/06032249_0976.MP4/01260.jpg
# driver_161_90frame/06032225_0968.MP4/00360.lines.txt
# driver_161_90frame/06030922_0776.MP4/00540.lines.txt
# driver_161_90frame/06040214_1044.MP4/04770.lines.txt
# driver_161_90frame/06030910_0772.MP4/00000.jpg
# driver_161_90frame/06031613_0867.MP4/01080.lines.txt
# driver_161_90frame/06031746_0898.MP4/04500.jpg
# driver_161_90frame/06032128_0949.MP4/03330.jpg
# driver_161_90frame/06032158_0959.MP4/04320.lines.txt
# driver_161_90frame/06031028_0798.MP4/03690.jpg
# driver_161_90frame/06031758_0902.MP4/02070.lines.txt
# driver_161_90frame/06032344_0994.MP4/05310.jpg
# driver_161_90frame/06031752_0900.MP4/04320.jpg
# driver_161_90frame/06031722_0890.MP4/01800.lines.txt
# driver_161_90frame/06031758_0902.MP4/02520.jpg
# driver_161_90frame/06030943_0783.MP4/03960.jpg
# driver_161_90frame/06031207_0831.MP4/03150.lines.txt
# driver_161_90frame/06031919_0929.MP4/00900.jpg
# driver_161_90frame/06031858_0922.MP4/01260.jpg
# driver_161_90frame/06032329_0989.MP4/04320.jpg
# driver_161_90frame/06040132_1030.MP4/03960.jpg
# driver_161_90frame/06031055_0807.MP4/02880.jpg
# driver_161_90frame/06031622_0870.MP4/05130.lines.txt
# driver_161_90frame/06030955_0787.MP4/00180.lines.txt
# driver_161_90frame/06030922_0776.MP4/04770.jpg
# driver_161_90frame/06031547_0858.MP4/01980.jpg
# driver_161_90frame/06031837_0915.MP4/02070.jpg
# driver_161_90frame/06030913_0773.MP4/04590.lines.txt
# driver_161_90frame/06040111_1023.MP4/01170.lines.txt
# driver_161_90frame/06032113_0944.MP4/01800.lines.txt
# driver_161_90frame/06040111_1023.MP4/04770.jpg
# driver_161_90frame/06032310_0983.MP4/03960.jpg
# driver_161_90frame/06030922_0776.MP4/00000.jpg
# driver_161_90frame/06031737_0895.MP4/05130.jpg
# driver_161_90frame/06031622_0870.MP4/03690.jpg
# driver_161_90frame/06031925_0931.MP4/02520.jpg
# driver_161_90frame/06040111_1023.MP4/00000.jpg
# driver_161_90frame/06030819_0755.MP4/05220.jpg
# driver_161_90frame/06031819_0909.MP4/01710.lines.txt
# driver_161_90frame/06030819_0755.MP4/04410.lines.txt
# driver_161_90frame/06032329_0989.MP4/02970.lines.txt
# driver_161_90frame/06032356_0998.MP4/05310.jpg
# driver_161_90frame/06031228_0838.MP4/01350.lines.txt
# driver_161_90frame/06031058_0808.MP4/01080.lines.txt
# driver_161_90frame/06040202_1040.MP4/01890.lines.txt
# driver_161_90frame/06032255_0978.MP4/02610.lines.txt
# driver_161_90frame/06040314_1064.MP4/01080.lines.txt
# driver_161_90frame/06031643_0877.MP4/03330.lines.txt
# driver_161_90frame/06032146_0955.MP4/01440.lines.txt
# driver_161_90frame/06030843_0763.MP4/01620.lines.txt
# driver_161_90frame/06031320_0848.MP4/00180.jpg
# driver_161_90frame/06032332_0990.MP4/02610.lines.txt
# driver_161_90frame/06030919_0775.MP4/00090.lines.txt
# driver_161_90frame/06031849_0919.MP4/02070.jpg
# driver_161_90frame/06031210_0832.MP4/02970.lines.txt
# driver_161_90frame/06031913_0927.MP4/02520.lines.txt
# driver_161_90frame/06040108_1022.MP4/01710.lines.txt
# driver_161_90frame/06032301_0980.MP4/04590.jpg
# driver_161_90frame/06040123_1027.MP4/04770.jpg
# driver_161_90frame/06032052_0937.MP4/02880.jpg
# driver_161_90frame/06032322_0987.MP4/03960.jpg
# driver_161_90frame/06040008_1002.MP4/05040.lines.txt
# driver_161_90frame/06031119_0815.MP4/02970.jpg
# driver_161_90frame/06031916_0928.MP4/03330.jpg
# driver_161_90frame/06040141_1033.MP4/03420.lines.txt
# driver_161_90frame/06040311_1063.MP4/03960.jpg
# driver_161_90frame/06031605_0864.MP4/03870.jpg
# driver_161_90frame/06032110_0943.MP4/03420.lines.txt
# driver_161_90frame/06032219_0966.MP4/04410.jpg
# driver_161_90frame/06040032_1010.MP4/02250.lines.txt
# driver_161_90frame/06031834_0914.MP4/02970.lines.txt
# driver_161_90frame/06032104_0941.MP4/02970.jpg
# driver_161_90frame/06030916_0774.MP4/02700.lines.txt
# driver_161_90frame/06032319_0986.MP4/03150.jpg
# driver_161_90frame/06032216_0965.MP4/
# driver_161_90frame/06031701_0883.MP4/04950.jpg
# driver_161_90frame/06031631_0873.MP4/00450.lines.txt
# driver_161_90frame/06031146_0824.MP4/03960.jpg
# driver_161_90frame/06032313_0984.MP4/03330.lines.txt
# driver_161_90frame/06031928_0932.MP4/03150.jpg
# driver_161_90frame/06030840_0762.MP4/03240.lines.txt
# driver_161_90frame/06032204_0961.MP4/02160.lines.txt
# driver_161_90frame/06030949_0785.MP4/02340.lines.txt
# driver_161_90frame/06031125_0817.MP4/04770.jpg
# driver_161_90frame/06032158_0959.MP4/03690.lines.txt
# driver_161_90frame/06040302_1060.MP4/04590.jpg
# driver_161_90frame/06031807_0905.MP4/05220.jpg
# driver_161_90frame/06031910_0926.MP4/04140.lines.txt
# driver_161_90frame/06040105_1021.MP4/03330.lines.txt
# driver_161_90frame/06040059_1019.MP4/04860.lines.txt
# driver_161_90frame/06031813_0907.MP4/01890.jpg
# driver_161_90frame/06032116_0945.MP4/02970.jpg
# driver_161_90frame/06031125_0817.MP4/00000.jpg
# driver_161_90frame/06031155_0827.MP4/00000.lines.txt
# driver_161_90frame/06032332_0990.MP4/04950.jpg
# driver_161_90frame/06032326_0988.MP4/05220.lines.txt
# driver_161_90frame/06031113_0813.MP4/04410.lines.txt
# driver_161_90frame/06031137_0821.MP4/04590.jpg
# driver_161_90frame/06031010_0792.MP4/00360.jpg
# driver_161_90frame/06040308_1062.MP4/03240.lines.txt
# driver_161_90frame/06031158_0828.MP4/03960.jpg
# driver_161_90frame/06032055_0938.MP4/00090.lines.txt
# driver_161_90frame/06032350_0996.MP4/02430.lines.txt
# driver_161_90frame/06030931_0779.MP4/05040.lines.txt
# driver_161_90frame/06040126_1028.MP4/01530.lines.txt
# driver_161_90frame/06031246_0844.MP4/00720.lines.txt
# driver_161_90frame/06030928_0778.MP4/04950.lines.txt
# driver_161_90frame/06032143_0954.MP4/03960.jpg
# driver_161_90frame/06031840_0916.MP4/02880.jpg
# driver_161_90frame/06031001_0789.MP4/03060.lines.txt
# driver_161_90frame/06030819_0755.MP4/03780.lines.txt
# driver_161_90frame/06040017_1005.MP4/00360.lines.txt
# driver_161_90frame/06032301_0980.MP4/00450.lines.txt
# driver_161_90frame/06031146_0824.MP4/04050.lines.txt
# driver_161_90frame/06032255_0978.MP4/01980.lines.txt
# driver_161_90frame/06032122_0947.MP4/04770.jpg
# driver_161_90frame/06032234_0971.MP4/04410.lines.txt
# driver_161_90frame/06040117_1025.MP4/02970.jpg
# driver_161_90frame/06030843_0763.MP4/00990.lines.txt
# driver_161_90frame/06031608_0865.MP4/02250.lines.txt
# driver_161_90frame/06040220_1046.MP4/02340.lines.txt
# driver_161_90frame/06030928_0778.MP4/02970.jpg
# driver_161_90frame/06040050_1016.MP4/02070.lines.txt
# driver_161_90frame/06032332_0990.MP4/01980.lines.txt
# driver_161_90frame/06031822_0910.MP4/00720.lines.txt
# driver_161_90frame/06032052_0937.MP4/02700.lines.txt
# driver_161_90frame/06032122_0947.MP4/00000.jpg
# driver_161_90frame/06031913_0927.MP4/01890.lines.txt
# driver_161_90frame/06040159_1039.MP4/01170.lines.txt
# driver_161_90frame/06031022_0796.MP4/00360.jpg
# driver_161_90frame/06031831_0913.MP4/05220.lines.txt
# driver_161_90frame/06031237_0841.MP4/04770.lines.txt
# driver_161_90frame/06030825_0757.MP4/01350.lines.txt
# driver_161_90frame/06031628_0872.MP4/01890.jpg
# driver_161_90frame/06032134_0951.MP4/04590.jpg
# driver_161_90frame/06031001_0789.MP4/01170.jpg
# driver_161_90frame/06032155_0958.MP4/03960.jpg
# driver_161_90frame/06031320_0848.MP4/04050.lines.txt
# driver_161_90frame/06040141_1033.MP4/02790.lines.txt
# driver_161_90frame/06030934_0780.MP4/04590.jpg
# driver_161_90frame/06031625_0871.MP4/02610.lines.txt
# driver_161_90frame/06030955_0787.MP4/03960.jpg
# driver_161_90frame/06031855_0921.MP4/00360.lines.txt
# driver_161_90frame/06030819_0755.MP4/04860.jpg
# driver_161_90frame/06031022_0796.MP4/00810.lines.txt
# driver_161_90frame/06040144_1034.MP4/03960.jpg
# driver_161_90frame/06031031_0799.MP4/05310.lines.txt
# driver_161_90frame/06032131_0950.MP4/
# driver_161_90frame/06040008_1002.MP4/04860.jpg
# driver_161_90frame/06031655_0881.MP4/02880.jpg
# driver_161_90frame/06040047_1015.MP4/02610.lines.txt
# driver_161_90frame/06031904_0924.MP4/02970.jpg
# driver_161_90frame/06031134_0820.MP4/01170.lines.txt
# driver_161_90frame/06032307_0982.MP4/02790.jpg
# driver_161_90frame/06040129_1029.MP4/02970.jpg
# driver_161_90frame/06031634_0874.MP4/03690.jpg
# driver_161_90frame/06031658_0882.MP4/02250.lines.txt
# driver_161_90frame/06040123_1027.MP4/00000.jpg
# driver_161_90frame/06031040_0802.MP4/00180.jpg
# driver_161_90frame/06031646_0878.MP4/00810.lines.txt
# driver_161_90frame/06031529_0852.MP4/03330.lines.txt
# driver_161_90frame/06031928_0932.MP4/01440.lines.txt
# driver_161_90frame/06030946_0784.MP4/04590.jpg
# driver_161_90frame/06031013_0793.MP4/04860.lines.txt
# driver_161_90frame/06030855_0767.MP4/03600.lines.txt
# driver_161_90frame/06032219_0966.MP4/02520.lines.txt
# driver_161_90frame/06031931_0933.MP4/03960.jpg
# driver_161_90frame/06040135_1031.MP4/04590.jpg
# driver_161_90frame/06032049_0936.MP4/02250.lines.txt
# driver_161_90frame/06031553_0860.MP4/00540.lines.txt
# driver_161_90frame/06040156_1038.MP4/03960.jpg
# driver_161_90frame/06031740_0896.MP4/01620.lines.txt
# driver_161_90frame/06031113_0813.MP4/03780.lines.txt
# driver_161_90frame/06032326_0988.MP4/04590.lines.txt
# driver_161_90frame/06031816_0908.MP4/03330.lines.txt
# driver_161_90frame/06031910_0926.MP4/04770.jpg
# driver_161_90frame/06031550_0859.MP4/03600.lines.txt
# driver_161_90frame/06032313_0984.MP4/04590.jpg
# driver_161_90frame/06032252_0977.MP4/04230.lines.txt
# driver_161_90frame/06031828_0912.MP4/04410.jpg
# driver_161_90frame/06032143_0954.MP4/03060.lines.txt
# driver_161_90frame/06031637_0875.MP4/04860.lines.txt
# driver_161_90frame/06031646_0878.MP4/03690.jpg
# driver_161_90frame/06031910_0926.MP4/00000.jpg
# driver_161_90frame/06031840_0916.MP4/00540.lines.txt
# driver_161_90frame/06040214_1044.MP4/04500.lines.txt
# driver_161_90frame/06040308_1062.MP4/02790.jpg
# driver_161_90frame/06040044_1014.MP4/04230.lines.txt
# driver_161_90frame/06031019_0795.MP4/00360.lines.txt
# driver_161_90frame/06031922_0930.MP4/04590.jpg
# driver_161_90frame/06031043_0803.MP4/00810.lines.txt
# driver_161_90frame/06040147_1035.MP4/04590.jpg
# driver_161_90frame/06031140_0822.MP4/00630.jpg
# driver_161_90frame/06032234_0971.MP4/03780.lines.txt
# driver_161_90frame/06031052_0806.MP4/05310.lines.txt
# driver_161_90frame/06032316_0985.MP4/00810.lines.txt
# driver_161_90frame/06031104_0810.MP4/00270.jpg
# driver_161_90frame/06031704_0884.MP4/01530.lines.txt
# driver_161_90frame/06031317_0847.MP4/00720.jpg
# driver_161_90frame/06040247_1055.MP4/04140.lines.txt
# driver_161_90frame/06031529_0852.MP4/04950.jpg
# driver_161_90frame/06031831_0913.MP4/04590.lines.txt
# driver_161_90frame/06032216_0965.MP4/04140.lines.txt
# driver_161_90frame/06030913_0773.MP4/04320.lines.txt
# driver_161_90frame/06031804_0904.MP4/00450.lines.txt
# driver_161_90frame/06031213_0833.MP4/00090.lines.txt
# driver_161_90frame/06031819_0909.MP4/05220.jpg
# driver_161_90frame/06032240_0973.MP4/01350.lines.txt
# driver_161_90frame/06031034_0800.MP4/04860.lines.txt
# driver_161_90frame/06031725_0891.MP4/04770.jpg
# driver_161_90frame/06032131_0950.MP4/00180.lines.txt
# driver_161_90frame/06032329_0989.MP4/02700.lines.txt
# driver_161_90frame/06031625_0871.MP4/01980.lines.txt
# driver_161_90frame/06031737_0895.MP4/01170.lines.txt
# driver_161_90frame/06032128_0949.MP4/02970.jpg
# driver_161_90frame/06032307_0982.MP4/04860.lines.txt
# driver_161_90frame/06040202_1040.MP4/01620.lines.txt
# driver_161_90frame/06031547_0858.MP4/03150.lines.txt
# driver_161_90frame/06032344_0994.MP4/04950.jpg
# driver_161_90frame/06031725_0891.MP4/00000.jpg
# driver_161_90frame/06031031_0799.MP4/04680.lines.txt
# driver_161_90frame/06031752_0900.MP4/03960.jpg
# driver_161_90frame/06031110_0812.MP4/02070.jpg
# driver_161_90frame/06031149_0825.MP4/04590.jpg
# driver_161_90frame/06040047_1015.MP4/01980.lines.txt
# driver_161_90frame/06031323_0849.MP4/02520.jpg
# driver_161_90frame/06031837_0915.MP4/00090.lines.txt
# driver_161_90frame/06032329_0989.MP4/03960.jpg
# driver_161_90frame/06031131_0819.MP4/01440.jpg
# driver_161_90frame/06032128_0949.MP4/01170.lines.txt
# driver_161_90frame/06031210_0832.MP4/02700.lines.txt
# driver_161_90frame/06031231_0839.MP4/00180.jpg
# driver_161_90frame/06031040_0802.MP4/02430.lines.txt
# driver_161_90frame/06031204_0830.MP4/00720.jpg
# driver_161_90frame/06040029_1009.MP4/02340.lines.txt
# driver_161_90frame/06040250_1056.MP4/03960.lines.txt
# driver_161_90frame/06031701_0883.MP4/03150.lines.txt
# driver_161_90frame/06040235_1051.MP4/01260.lines.txt
# driver_161_90frame/06031219_0835.MP4/05130.lines.txt
# driver_161_90frame/06030822_0756.MP4/00900.jpg
# driver_161_90frame/06031317_0847.MP4/03960.lines.txt
# driver_161_90frame/06031737_0895.MP4/04770.jpg
# driver_161_90frame/06032110_0943.MP4/02790.lines.txt
# driver_161_90frame/06032356_0998.MP4/04950.jpg
# driver_161_90frame/06040011_1003.MP4/00900.jpg
# driver_161_90frame/06030855_0767.MP4/02970.lines.txt
# driver_161_90frame/06031737_0895.MP4/00000.jpg
# driver_161_90frame/06032219_0966.MP4/01890.lines.txt
# driver_161_90frame/06030901_0769.MP4/00450.jpg
# driver_161_90frame/06032137_0952.MP4/05220.lines.txt
# driver_161_90frame/06031243_0843.MP4/02340.lines.txt
# driver_161_90frame/06032344_0994.MP4/03960.lines.txt
# driver_161_90frame/06031834_0914.MP4/02700.lines.txt
# driver_161_90frame/06040011_1003.MP4/03960.lines.txt
# driver_161_90frame/06040123_1027.MP4/03150.lines.txt
# driver_161_90frame/06032353_0997.MP4/
# driver_161_90frame/06031231_0839.MP4/00900.lines.txt
# driver_161_90frame/06031740_0896.MP4/00990.lines.txt
# driver_161_90frame/06040050_1016.MP4/00180.jpg
# driver_161_90frame/06031550_0859.MP4/02970.lines.txt
# driver_161_90frame/06031535_0854.MP4/00270.lines.txt
# driver_161_90frame/06031323_0849.MP4/01530.lines.txt
# driver_161_90frame/06031131_0819.MP4/04230.lines.txt
# driver_161_90frame/06031007_0791.MP4/00900.jpg
# driver_161_90frame/06032146_0955.MP4/04590.jpg
# driver_161_90frame/06031210_0832.MP4/02520.jpg
# driver_161_90frame/06040214_1044.MP4/03870.lines.txt
# driver_161_90frame/06031613_0867.MP4/00180.lines.txt
# driver_161_90frame/06030913_0773.MP4/00270.jpg
# driver_161_90frame/06032158_0959.MP4/03420.lines.txt
# driver_161_90frame/06040102_1020.MP4/00270.jpg
# driver_161_90frame/06031758_0902.MP4/01170.lines.txt
# driver_161_90frame/06031222_0836.MP4/04950.lines.txt
# driver_161_90frame/06031207_0831.MP4/02250.lines.txt
# driver_161_90frame/06031052_0806.MP4/04680.lines.txt
# driver_161_90frame/06031755_0901.MP4/04590.jpg
# driver_161_90frame/06031916_0928.MP4/02970.jpg
# driver_161_90frame/06031559_0862.MP4/04950.lines.txt
# driver_161_90frame/06032319_0986.MP4/02790.jpg
# driver_161_90frame/06031622_0870.MP4/04230.lines.txt
# driver_161_90frame/06031013_0793.MP4/02700.jpg
# driver_161_90frame/06040144_1034.MP4/00900.lines.txt
# driver_161_90frame/06030940_0782.MP4/01260.jpg
# driver_161_90frame/06030913_0773.MP4/03690.lines.txt
# driver_161_90frame/06040111_1023.MP4/00270.lines.txt
# driver_161_90frame/06031019_0795.MP4/00900.jpg
# driver_161_90frame/06032113_0944.MP4/00900.lines.txt
# driver_161_90frame/06032158_0959.MP4/04590.jpg
# driver_161_90frame/06031052_0806.MP4/00180.jpg
# driver_161_90frame/06040150_1036.MP4/00630.jpg
# driver_161_90frame/06031846_0918.MP4/04950.lines.txt
# driver_161_90frame/06031749_0899.MP4/
# driver_161_90frame/06030958_0788.MP4/04590.jpg
# driver_161_90frame/06031619_0869.MP4/05220.lines.txt
# driver_161_90frame/06031928_0932.MP4/02790.jpg
# driver_161_90frame/06030819_0755.MP4/03510.lines.txt
# driver_161_90frame/06031201_0829.MP4/03330.jpg
# driver_161_90frame/06031819_0909.MP4/00810.lines.txt
# driver_161_90frame/06031228_0838.MP4/00450.lines.txt
# driver_161_90frame/06032104_0941.MP4/04950.lines.txt
# driver_161_90frame/06031058_0808.MP4/00180.lines.txt
# driver_161_90frame/06031807_0905.MP4/04860.jpg
# driver_161_90frame/06040202_1040.MP4/00990.lines.txt
# driver_161_90frame/06032255_0978.MP4/01710.lines.txt
# driver_161_90frame/06040314_1064.MP4/00180.lines.txt
# driver_161_90frame/06031643_0877.MP4/02430.lines.txt
# driver_161_90frame/06031640_0876.MP4/00360.jpg
# driver_161_90frame/06032146_0955.MP4/00540.lines.txt
# driver_161_90frame/06030843_0763.MP4/00720.lines.txt
# driver_161_90frame/06040202_1040.MP4/00720.jpg
# driver_161_90frame/06040135_1031.MP4/04950.lines.txt
# driver_161_90frame/06031925_0931.MP4/03060.lines.txt
# driver_161_90frame/06032155_0958.MP4/05040.lines.txt
# driver_161_90frame/06030852_0766.MP4/05220.lines.txt
# driver_161_90frame/06032332_0990.MP4/01710.lines.txt
# driver_161_90frame/06031004_0790.MP4/03330.jpg
# driver_161_90frame/06031913_0927.MP4/01620.lines.txt
# driver_161_90frame/06040108_1022.MP4/00810.lines.txt
# driver_161_90frame/06031025_0797.MP4/02700.jpg
# driver_161_90frame/06031237_0841.MP4/04500.lines.txt
# driver_161_90frame/06040117_1025.MP4/05310.lines.txt
# driver_161_90frame/06030846_0764.MP4/
# driver_161_90frame/06040008_1002.MP4/04140.lines.txt
# driver_161_90frame/06031550_0859.MP4/01080.jpg
# driver_161_90frame/06031037_0801.MP4/00720.jpg
# driver_161_90frame/06040120_1026.MP4/02070.jpg
# driver_161_90frame/06040141_1033.MP4/02520.lines.txt
# driver_161_90frame/06040159_1039.MP4/04590.jpg
# driver_161_90frame/06031152_0826.MP4/00630.jpg
# driver_161_90frame/06032137_0952.MP4/04590.lines.txt
# driver_161_90frame/06030834_0760.MP4/04770.lines.txt
# driver_161_90frame/06040032_1010.MP4/01350.lines.txt
# driver_161_90frame/06031116_0814.MP4/00270.jpg
# driver_161_90frame/06031602_0863.MP4/01170.jpg
# driver_161_90frame/06031016_0794.MP4/03330.jpg
# driver_161_90frame/06031010_0792.MP4/05130.jpg
# driver_161_90frame/06032101_0940.MP4/00270.jpg
# driver_161_90frame/06031149_0825.MP4/01530.lines.txt
# driver_161_90frame/06031740_0896.MP4/00810.jpg
# driver_161_90frame/06031031_0799.MP4/04500.jpg
# driver_161_90frame/06032313_0984.MP4/02430.lines.txt
# driver_161_90frame/06030840_0762.MP4/02340.lines.txt
# driver_161_90frame/06032204_0961.MP4/01260.lines.txt
# driver_161_90frame/06031043_0803.MP4/02520.jpg
# driver_161_90frame/06032158_0959.MP4/02790.lines.txt
# driver_161_90frame/06031143_0823.MP4/01260.jpg
# driver_161_90frame/06040105_1021.MP4/02430.lines.txt
# driver_161_90frame/06031801_0903.MP4/02070.lines.txt
# driver_161_90frame/06031128_0818.MP4/00270.jpg
# driver_161_90frame/06031122_0816.MP4/02070.jpg
# driver_161_90frame/06040220_1046.MP4/02520.jpg
# driver_161_90frame/06031113_0813.MP4/03510.lines.txt
# driver_161_90frame/06030834_0760.MP4/00720.jpg
# driver_161_90frame/06032326_0988.MP4/04320.lines.txt
# driver_161_90frame/06031022_0796.MP4/05130.jpg
# driver_161_90frame/06030934_0780.MP4/01080.lines.txt
# driver_161_90frame/06032113_0944.MP4/00270.jpg
# driver_161_90frame/06031216_0834.MP4/00720.jpg
# driver_161_90frame/06040308_1062.MP4/02340.lines.txt
# driver_161_90frame/06040153_1037.MP4/04770.lines.txt
# driver_161_90frame/06032350_0996.MP4/01530.lines.txt
# driver_161_90frame/06032122_0947.MP4/04770.lines.txt
# driver_161_90frame/06032350_0996.MP4/01620.jpg
# driver_161_90frame/06030931_0779.MP4/04140.lines.txt
# driver_161_90frame/06031001_0789.MP4/02160.lines.txt
# driver_161_90frame/06040002_1000.MP4/01530.jpg
# driver_161_90frame/06031034_0800.MP4/03150.jpg
# driver_161_90frame/06040126_1028.MP4/00630.lines.txt
# driver_161_90frame/06032201_0960.MP4/00720.jpg
# driver_161_90frame/06031619_0869.MP4/04590.lines.txt
# driver_161_90frame/06040023_1007.MP4/00900.jpg
# driver_161_90frame/06030819_0755.MP4/02880.lines.txt
# driver_161_90frame/06031155_0827.MP4/01260.jpg
# driver_161_90frame/06031541_0856.MP4/03420.jpg
# driver_161_90frame/06031146_0824.MP4/03150.lines.txt
# driver_161_90frame/06031749_0899.MP4/00000.jpg
# driver_161_90frame/06040050_1016.MP4/01170.lines.txt
# driver_161_90frame/06032234_0971.MP4/03510.lines.txt
# driver_161_90frame/06032140_0953.MP4/01260.jpg
# driver_161_90frame/06031608_0865.MP4/01350.lines.txt
# driver_161_90frame/06031243_0843.MP4/01710.jpg
# driver_161_90frame/06040220_1046.MP4/01440.lines.txt
# driver_161_90frame/06030846_0764.MP4/00720.jpg
# driver_161_90frame/06030840_0762.MP4/02520.jpg
# driver_161_90frame/06030852_0766.MP4/04590.lines.txt
# driver_161_90frame/06031222_0836.MP4/02520.jpg
# driver_161_90frame/06032052_0937.MP4/01800.lines.txt
# driver_161_90frame/06031913_0927.MP4/00990.lines.txt
# driver_161_90frame/06031207_0831.MP4/01350.jpg
# driver_161_90frame/06040159_1039.MP4/00270.lines.txt
# driver_161_90frame/06040035_1011.MP4/00720.jpg
# driver_161_90frame/06031831_0913.MP4/04320.lines.txt
# driver_161_90frame/06031228_0838.MP4/00720.jpg
# driver_161_90frame/06030825_0757.MP4/00450.lines.txt
# driver_161_90frame/06031237_0841.MP4/03870.lines.txt
# driver_161_90frame/06040117_1025.MP4/04680.lines.txt
# driver_161_90frame/06030825_0757.MP4/01530.jpg
# driver_161_90frame/06030925_0777.MP4/00270.jpg
# driver_161_90frame/06031810_0906.MP4/00900.jpg
# driver_161_90frame/06040014_1004.MP4/01530.jpg
# driver_161_90frame/06032213_0964.MP4/00720.jpg
# driver_161_90frame/06040114_1024.MP4/00270.jpg
# driver_161_90frame/06031320_0848.MP4/03150.lines.txt
# driver_161_90frame/06040141_1033.MP4/01890.lines.txt
# driver_161_90frame/06040253_1057.MP4/01080.lines.txt
# driver_161_90frame/06031625_0871.MP4/01710.lines.txt
# driver_161_90frame/06032231_0970.MP4/05130.lines.txt
# driver_161_90frame/06032222_0967.MP4/01080.lines.txt
# driver_161_90frame/06031134_0820.MP4/03600.jpg
# driver_161_90frame/06031234_0840.MP4/02340.jpg
# driver_161_90frame/06032152_0957.MP4/01260.jpg
# driver_161_90frame/06030952_0786.MP4/01260.jpg
# driver_161_90frame/06030858_0768.MP4/00090.lines.txt
# driver_161_90frame/06031031_0799.MP4/04410.lines.txt
# driver_161_90frame/06030937_0781.MP4/00090.jpg
# driver_161_90frame/06030852_0766.MP4/02520.jpg
# driver_161_90frame/06040047_1015.MP4/01710.lines.txt
# driver_161_90frame/06032347_0995.MP4/01080.lines.txt
# driver_161_90frame/06031113_0813.MP4/04410.jpg
# driver_161_90frame/06040014_1004.MP4/01080.lines.txt
# driver_161_90frame/06031213_0833.MP4/03150.jpg
# driver_161_90frame/06040041_1013.MP4/02520.jpg
# driver_161_90frame/06032240_0973.MP4/01710.jpg
# driver_161_90frame/06040141_1033.MP4/01260.jpg
# driver_161_90frame/06030831_0759.MP4/03330.jpg
# driver_161_90frame/06040005_1001.MP4/02160.jpg
# driver_161_90frame/06031801_0903.MP4/01530.jpg
# driver_161_90frame/06031658_0882.MP4/01350.lines.txt
# driver_161_90frame/06030931_0779.MP4/02070.jpg
# driver_161_90frame/06032204_0961.MP4/01350.jpg
# driver_161_90frame/06031901_0923.MP4/00270.jpg
# driver_161_90frame/06031652_0880.MP4/00180.jpg
# driver_161_90frame/06040026_1008.MP4/01530.jpg
# driver_161_90frame/06040020_1006.MP4/03330.jpg
# driver_161_90frame/06032304_0981.MP4/00090.jpg
# driver_161_90frame/06040126_1028.MP4/00270.jpg
# driver_161_90frame/06031529_0852.MP4/02430.lines.txt
# driver_161_90frame/06030904_0770.MP4/02610.jpg
# driver_161_90frame/06032110_0943.MP4/02520.lines.txt
# driver_161_90frame/06031013_0793.MP4/03960.lines.txt
# driver_161_90frame/06031819_0909.MP4/04860.jpg
# driver_161_90frame/06032219_0966.MP4/01620.lines.txt
# driver_161_90frame/06030916_0774.MP4/01800.lines.txt
# driver_161_90frame/06031816_0908.MP4/02430.lines.txt
# driver_161_90frame/06032049_0936.MP4/01350.lines.txt
# driver_161_90frame/06040214_1044.MP4/00720.jpg
# driver_161_90frame/06031240_0842.MP4/04140.jpg
# driver_161_90frame/06032326_0988.MP4/03690.lines.txt
# driver_161_90frame/06030843_0763.MP4/03150.jpg
# driver_161_90frame/06032143_0954.MP4/02160.lines.txt
# driver_161_90frame/06031625_0871.MP4/00900.jpg
# driver_161_90frame/06031104_0810.MP4/05040.jpg
# driver_161_90frame/06031740_0896.MP4/00720.lines.txt
# driver_161_90frame/06031113_0813.MP4/02880.lines.txt
# driver_161_90frame/06032231_0970.MP4/02340.jpg
# driver_161_90frame/06031225_0837.MP4/02070.lines.txt
# driver_161_90frame/06040032_1010.MP4/03150.jpg
# driver_161_90frame/06031550_0859.MP4/02700.lines.txt
# driver_161_90frame/06031225_0837.MP4/03150.jpg
# driver_161_90frame/06040053_1017.MP4/02520.jpg
# driver_161_90frame/06032252_0977.MP4/03330.lines.txt
# driver_161_90frame/06031535_0854.MP4/00000.lines.txt
# driver_161_90frame/06031637_0875.MP4/03960.lines.txt
# driver_161_90frame/06032252_0977.MP4/01710.jpg
# driver_161_90frame/06040153_1037.MP4/01260.jpg
# driver_161_90frame/06031640_0876.MP4/04050.lines.txt
# driver_161_90frame/06040135_1031.MP4/
# driver_161_90frame/06032110_0943.MP4/04410.jpg
# driver_161_90frame/06031704_0884.MP4/00450.jpg
# driver_161_90frame/06031556_0861.MP4/00810.jpg
# driver_161_90frame/06031749_0899.MP4/03150.lines.txt
# driver_161_90frame/06031010_0792.MP4/04770.jpg
# driver_161_90frame/06030949_0785.MP4/01440.lines.txt
# driver_161_90frame/06032210_0963.MP4/03150.jpg
# driver_161_90frame/06040214_1044.MP4/03600.lines.txt
# driver_161_90frame/06031049_0805.MP4/00720.jpg
# driver_161_90frame/06030901_0769.MP4/05220.jpg
# driver_161_90frame/06031910_0926.MP4/03240.lines.txt
# driver_161_90frame/06030916_0774.MP4/02610.jpg
# driver_161_90frame/06030910_0772.MP4/04410.jpg
# driver_161_90frame/06040241_1053.MP4/01710.jpg
# driver_161_90frame/06031535_0854.MP4/01620.jpg
# driver_161_90frame/06040059_1019.MP4/03960.lines.txt
# driver_161_90frame/06040105_1021.MP4/02610.jpg
# driver_161_90frame/06031849_0919.MP4/02070.lines.txt
# driver_161_90frame/06032304_0981.MP4/01800.jpg
# driver_161_90frame/06040205_1041.MP4/01350.jpg
# driver_161_90frame/06031731_0893.MP4/04770.lines.txt
# driver_161_90frame/06032234_0971.MP4/02880.lines.txt
# driver_161_90frame/06040305_1061.MP4/00090.jpg
# driver_161_90frame/06040226_1048.MP4/00720.jpg
# driver_161_90frame/06031252_0846.MP4/04140.jpg
# driver_161_90frame/06031052_0806.MP4/04410.lines.txt
# driver_161_90frame/06031631_0873.MP4/02700.jpg
# driver_161_90frame/06031731_0893.MP4/01440.jpg
# driver_161_90frame/06031526_0851.MP4/04050.lines.txt
# driver_161_90frame/06031704_0884.MP4/00630.lines.txt
# driver_161_90frame/06031028_0798.MP4/03330.jpg
# driver_161_90frame/06040247_1055.MP4/03240.lines.txt
# driver_161_90frame/06040111_1023.MP4/00000.lines.txt
# driver_161_90frame/06031610_0866.MP4/03510.jpg
# driver_161_90frame/06031831_0913.MP4/03690.lines.txt
# driver_161_90frame/06032335_0991.MP4/00450.jpg
# driver_161_90frame/06032216_0965.MP4/03240.lines.txt
# driver_161_90frame/06030913_0773.MP4/03420.lines.txt
# driver_161_90frame/06031616_0868.MP4/01710.jpg
# driver_161_90frame/06040138_1032.MP4/02070.lines.txt
# driver_161_90frame/06030943_0783.MP4/03600.jpg
# driver_161_90frame/06032107_0942.MP4/02070.lines.txt
# driver_161_90frame/06032222_0967.MP4/03150.jpg
# driver_161_90frame/06040132_1030.MP4/03600.jpg
# driver_161_90frame/06031055_0807.MP4/02520.jpg
# driver_161_90frame/06040232_1050.MP4/02340.jpg
# driver_161_90frame/06031526_0851.MP4/02250.jpg
# driver_161_90frame/06032240_0973.MP4/00450.lines.txt
# driver_161_90frame/06030922_0776.MP4/04410.jpg
# driver_161_90frame/06040253_1057.MP4/01710.jpg
# driver_161_90frame/06031034_0800.MP4/03960.lines.txt
# driver_161_90frame/06031547_0858.MP4/01620.jpg
# driver_161_90frame/06032329_0989.MP4/01800.lines.txt
# driver_161_90frame/06032310_0983.MP4/04050.lines.txt
# driver_161_90frame/06031737_0895.MP4/00270.lines.txt
# driver_161_90frame/06040111_1023.MP4/04410.jpg
# driver_161_90frame/06032046_0935.MP4/00720.jpg
# driver_161_90frame/06032310_0983.MP4/03600.jpg
# driver_161_90frame/06040211_1043.MP4/03150.jpg
# driver_161_90frame/06040202_1040.MP4/00720.lines.txt
# driver_161_90frame/06031101_0809.MP4/01080.lines.txt
# driver_161_90frame/06031547_0858.MP4/02250.lines.txt
# driver_161_90frame/06031622_0870.MP4/03330.jpg
# driver_161_90frame/06030946_0784.MP4/03060.lines.txt
# driver_161_90frame/06031722_0890.MP4/02070.jpg
# driver_161_90frame/06031031_0799.MP4/03780.lines.txt
# driver_161_90frame/06031643_0877.MP4/02700.jpg
# driver_161_90frame/06031107_0811.MP4/02610.jpg
# driver_161_90frame/06031743_0897.MP4/01440.jpg
# driver_161_90frame/06040102_1020.MP4/04050.lines.txt
# driver_161_90frame/06032125_0948.MP4/00270.jpg
# driver_161_90frame/06040305_1061.MP4/01800.jpg
# driver_161_90frame/06031320_0848.MP4/04590.jpg
# driver_161_90frame/06032128_0949.MP4/00270.lines.txt
# driver_161_90frame/06031210_0832.MP4/01800.lines.txt
# driver_161_90frame/06032341_0993.MP4/02250.jpg
# driver_161_90frame/06031707_0885.MP4/01080.jpg
# driver_161_90frame/06031553_0860.MP4/03240.jpg
# driver_161_90frame/06040029_1009.MP4/01440.lines.txt
# driver_161_90frame/06031046_0804.MP4/03150.jpg
# driver_161_90frame/06031110_0812.MP4/05130.lines.txt
# driver_161_90frame/06030913_0773.MP4/05040.jpg
# driver_161_90frame/06032326_0988.MP4/01260.jpg
# driver_161_90frame/06040235_1051.MP4/00360.lines.txt
# driver_161_90frame/06040244_1054.MP4/02340.jpg
# driver_161_90frame/06031219_0835.MP4/04230.lines.txt
# driver_161_90frame/06031532_0853.MP4/04050.jpg
# driver_161_90frame/06032219_0966.MP4/00990.lines.txt
# driver_161_90frame/06032301_0980.MP4/04230.jpg
# driver_161_90frame/06031752_0900.MP4/04770.lines.txt
# driver_161_90frame/06040102_1020.MP4/05040.jpg
# driver_161_90frame/06032110_0943.MP4/01890.lines.txt
# driver_161_90frame/06032322_0987.MP4/03600.jpg
# driver_161_90frame/06032137_0952.MP4/04320.lines.txt
# driver_161_90frame/06040123_1027.MP4/04410.jpg
# driver_161_90frame/06032137_0952.MP4/00090.jpg
# driver_161_90frame/06032058_0939.MP4/00720.jpg
# driver_161_90frame/06032052_0937.MP4/02520.jpg
# driver_161_90frame/06040223_1047.MP4/03150.jpg
# driver_161_90frame/06031201_0829.MP4/02970.jpg
# driver_161_90frame/06030834_0760.MP4/04500.lines.txt
# driver_161_90frame/06031834_0914.MP4/01800.lines.txt
# driver_161_90frame/06031243_0843.MP4/01440.lines.txt
# driver_161_90frame/06030837_0761.MP4/01350.jpg
# driver_161_90frame/06040123_1027.MP4/02250.lines.txt
# driver_161_90frame/06031822_0910.MP4/00720.jpg
# driver_161_90frame/06030858_0768.MP4/00720.jpg
# driver_161_90frame/06031734_0894.MP4/02070.jpg
# driver_161_90frame/06031119_0815.MP4/02610.jpg
# driver_161_90frame/06031134_0820.MP4/00270.lines.txt
# driver_161_90frame/06031219_0835.MP4/01350.jpg
# driver_161_90frame/06040047_1015.MP4/00720.jpg
# driver_161_90frame/06040311_1063.MP4/03600.jpg
# driver_161_90frame/06031605_0864.MP4/03510.jpg
# driver_161_90frame/06031613_0867.MP4/04140.jpg
# driver_161_90frame/06032353_0997.MP4/02250.jpg
# driver_161_90frame/06031131_0819.MP4/03330.lines.txt
# driver_161_90frame/06032104_0941.MP4/02610.jpg
# driver_161_90frame/06031004_0790.MP4/02970.jpg
# driver_161_90frame/06031058_0808.MP4/03150.jpg
# driver_161_90frame/06032225_0968.MP4/00720.jpg
# driver_161_90frame/06040214_1044.MP4/02970.lines.txt
# driver_161_90frame/06040250_1056.MP4/04140.jpg
# driver_161_90frame/06031544_0857.MP4/04050.jpg
# driver_161_90frame/06031928_0932.MP4/00540.lines.txt
# driver_161_90frame/06032158_0959.MP4/02520.lines.txt
# driver_161_90frame/06030855_0767.MP4/02700.lines.txt
# driver_161_90frame/06032043_0934.MP4/03150.jpg
# driver_161_90frame/06031758_0902.MP4/00270.lines.txt
# driver_161_90frame/06030822_0756.MP4/02070.lines.txt
# driver_161_90frame/06032216_0965.MP4/01350.jpg
# driver_161_90frame/06031146_0824.MP4/03600.jpg
# driver_161_90frame/06031246_0844.MP4/02340.jpg
# driver_161_90frame/06030849_0765.MP4/01350.jpg
# driver_161_90frame/06031640_0876.MP4/05130.jpg
# driver_161_90frame/06031207_0831.MP4/01350.lines.txt
# driver_161_90frame/06031052_0806.MP4/03780.lines.txt
# driver_161_90frame/06030949_0785.MP4/00090.jpg
# driver_161_90frame/06032137_0952.MP4/01800.jpg
# driver_161_90frame/06040038_1012.MP4/01350.jpg
# driver_161_90frame/06031834_0914.MP4/00720.jpg
# driver_161_90frame/06032131_0950.MP4/03600.jpg
# driver_161_90frame/06031125_0817.MP4/04410.jpg
# driver_161_90frame/06040302_1060.MP4/04230.jpg
# driver_161_90frame/06040059_1019.MP4/00720.jpg
# driver_161_90frame/06032237_0972.MP4/00540.jpg
# driver_161_90frame/06040138_1032.MP4/00090.jpg
# driver_161_90frame/06031622_0870.MP4/03330.lines.txt
# driver_161_90frame/06030828_0758.MP4/02160.jpg
# driver_161_90frame/06040223_1047.MP4/
# driver_161_90frame/06031852_0920.MP4/01080.lines.txt
# driver_161_90frame/06030937_0781.MP4/01800.jpg
# ...
# driver_161_90frame/06032359_0999.MP4/02340.lines.txt
# driver_161_90frame/06040023_1007.MP4/03780.jpg
# driver_161_90frame/06040026_1008.MP4/02340.lines.txt
# driver_161_90frame/06031207_0831.MP4/00630.lines.txt
# driver_161_90frame/06032222_0967.MP4/02970.jpg
# driver_161_90frame/06031231_0839.MP4/00000.jpg
# driver_161_90frame/06040232_1050.MP4/01260.lines.txt
# driver_161_90frame/06031037_0801.MP4/00360.lines.txt
# driver_161_90frame/06031649_0879.MP4/04140.jpg
# driver_161_90frame/06031216_0834.MP4/05130.lines.txt
# driver_161_90frame/06031837_0915.MP4/01530.jpg
# driver_161_90frame/06032216_0965.MP4/01890.lines.txt
# driver_161_90frame/06031243_0843.MP4/04590.jpg
# driver_161_90frame/06032134_0951.MP4/05220.lines.txt
# driver_161_90frame/06032341_0993.MP4/03960.lines.txt
# driver_161_90frame/06031858_0922.MP4/04770.lines.txt
# driver_161_90frame/06031240_0842.MP4/02340.lines.txt
# driver_161_90frame/06040120_1026.MP4/03150.lines.txt
# driver_161_90frame/06031019_0795.MP4/03780.jpg
# driver_161_90frame/06040229_1049.MP4/02250.lines.txt
# driver_161_90frame/06031001_0789.MP4/00630.jpg
# driver_161_90frame/06040008_1002.MP4/01890.lines.txt
# driver_161_90frame/06040050_1016.MP4/04770.jpg
# driver_161_90frame/06031810_0906.MP4/03780.jpg
# driver_161_90frame/06031655_0881.MP4/02250.lines.txt
# driver_161_90frame/06040050_1016.MP4/00000.jpg
# driver_161_90frame/06040211_1043.MP4/03870.lines.txt
# driver_161_90frame/06040102_1020.MP4/04860.jpg
# driver_161_90frame/06030913_0773.MP4/04860.jpg
# driver_161_90frame/06031610_0866.MP4/00180.lines.txt
# driver_161_90frame/06031828_0912.MP4/02160.jpg
# driver_161_90frame/06031925_0931.MP4/01440.lines.txt
# driver_161_90frame/06031849_0919.MP4/01530.jpg
# driver_161_90frame/06032155_0958.MP4/03420.lines.txt
# driver_161_90frame/06030852_0766.MP4/03600.lines.txt
# driver_161_90frame/06031755_0901.MP4/01170.lines.txt
# driver_161_90frame/06031728_0892.MP4/05220.jpg
# driver_161_90frame/06030928_0778.MP4/02070.lines.txt
# driver_161_90frame/06040223_1047.MP4/02970.jpg
# driver_161_90frame/06031204_0830.MP4/02250.lines.txt
# driver_161_90frame/06031734_0894.MP4/01890.jpg
# driver_161_90frame/06031556_0861.MP4/04950.lines.txt
# driver_161_90frame/06031158_0828.MP4/03780.lines.txt
# driver_161_90frame/06032240_0973.MP4/04590.jpg
# driver_161_90frame/06031613_0867.MP4/03960.jpg
# driver_161_90frame/06031728_0892.MP4/03330.lines.txt
# driver_161_90frame/06031201_0829.MP4/05310.lines.txt
# driver_161_90frame/06031529_0852.MP4/00810.lines.txt
# driver_161_90frame/06031755_0901.MP4/04410.jpg
# driver_161_90frame/06040141_1033.MP4/00900.lines.txt
# driver_161_90frame/06030910_0772.MP4/03690.lines.txt
# driver_161_90frame/06031855_0921.MP4/03150.jpg
# driver_161_90frame/06032110_0943.MP4/00900.lines.txt
# driver_161_90frame/06032143_0954.MP4/00540.lines.txt
# driver_161_90frame/06031058_0808.MP4/02970.jpg
# driver_161_90frame/06040235_1051.MP4/02790.jpg
# driver_161_90frame/06040259_1059.MP4/04500.lines.txt
# driver_161_90frame/06031544_0857.MP4/03870.jpg
# driver_161_90frame/06030925_0777.MP4/04860.jpg
# driver_161_90frame/06040041_1013.MP4/04230.lines.txt
# driver_161_90frame/06031843_0917.MP4/04950.lines.txt
# driver_161_90frame/06031252_0846.MP4/04590.lines.txt
# driver_161_90frame/06040250_1056.MP4/03960.jpg
# driver_161_90frame/06032137_0952.MP4/05040.jpg
# driver_161_90frame/06031616_0868.MP4/05220.lines.txt
# driver_161_90frame/06032158_0959.MP4/04410.jpg
# driver_161_90frame/06040114_1024.MP4/04860.jpg
# driver_161_90frame/06032119_0946.MP4/03330.lines.txt
# driver_161_90frame/06031816_0908.MP4/00810.lines.txt
# driver_161_90frame/06032258_0979.MP4/03150.jpg
# driver_161_90frame/06031225_0837.MP4/00450.lines.txt
# driver_161_90frame/06031625_0871.MP4/03780.jpg
# driver_161_90frame/06040311_1063.MP4/00180.lines.txt
# driver_161_90frame/06031928_0932.MP4/02610.jpg
# driver_161_90frame/06032313_0984.MP4/00810.lines.txt
# driver_161_90frame/06031640_0876.MP4/04950.jpg
# driver_161_90frame/06031640_0876.MP4/02430.lines.txt
# driver_161_90frame/06032255_0978.MP4/
# driver_161_90frame/06031746_0898.MP4/01890.jpg
# driver_161_90frame/06030840_0762.MP4/00720.lines.txt
# driver_161_90frame/06032322_0987.MP4/05310.lines.txt
# driver_161_90frame/06031749_0899.MP4/01530.lines.txt
# driver_161_90frame/06040132_1030.MP4/04950.lines.txt
# driver_161_90frame/06030931_0779.MP4/01890.lines.txt
# driver_161_90frame/06031922_0930.MP4/03060.lines.txt
# driver_161_90frame/06032152_0957.MP4/05040.lines.txt
# driver_161_90frame/06032101_0940.MP4/04950.lines.txt
# driver_161_90frame/06031907_0925.MP4/03420.jpg
# driver_161_90frame/06031556_0861.MP4/03690.jpg
# driver_161_90frame/06031910_0926.MP4/01620.lines.txt
# driver_161_90frame/06030958_0788.MP4/04320.lines.txt
# driver_161_90frame/06040105_1021.MP4/00810.lines.txt
# driver_161_90frame/06031323_0849.MP4/00270.jpg
# driver_161_90frame/06031234_0840.MP4/04500.lines.txt
# driver_161_90frame/06030849_0765.MP4/03150.lines.txt
# driver_161_90frame/06040114_1024.MP4/05310.lines.txt
# driver_161_90frame/06040241_1053.MP4/04590.jpg
# driver_161_90frame/06032338_0992.MP4/04140.lines.txt
# driver_161_90frame/06040005_1001.MP4/04140.lines.txt
# driver_161_90frame/06032149_0956.MP4/05040.jpg
# driver_161_90frame/06031652_0880.MP4/04770.jpg
# driver_161_90frame/06031919_0929.MP4/04050.lines.txt
# driver_161_90frame/06031622_0870.MP4/01980.lines.txt
# driver_161_90frame/06032055_0938.MP4/02970.jpg
# driver_161_90frame/06032304_0981.MP4/04860.lines.txt
# driver_161_90frame/06040247_1055.MP4/01620.lines.txt
# driver_161_90frame/06032134_0951.MP4/04590.lines.txt
# driver_161_90frame/06031652_0880.MP4/00000.jpg
# driver_161_90frame/06040138_1032.MP4/00450.lines.txt
# driver_161_90frame/06040159_1039.MP4/04410.jpg
# driver_161_90frame/06032107_0942.MP4/00450.lines.txt
# driver_161_90frame/06031919_0929.MP4/03420.jpg
# driver_161_90frame/06031804_0904.MP4/01980.jpg
# driver_161_90frame/06031146_0824.MP4/01530.lines.txt
# driver_161_90frame/06040029_1009.MP4/01980.jpg
# driver_161_90frame/06032310_0983.MP4/02430.lines.txt
# driver_161_90frame/06040253_1057.MP4/04590.jpg
# driver_161_90frame/06032201_0960.MP4/01260.lines.txt
# driver_161_90frame/06032155_0958.MP4/02790.lines.txt
# driver_161_90frame/06030852_0766.MP4/02970.lines.txt
# driver_161_90frame/06031210_0832.MP4/00270.jpg
# driver_161_90frame/06031249_0845.MP4/02790.jpg
# driver_161_90frame/06030837_0761.MP4/00270.lines.txt
# driver_161_90frame/06031831_0913.MP4/02700.lines.txt
# driver_161_90frame/06031925_0931.MP4/05040.jpg
# driver_161_90frame/06031907_0925.MP4/01170.lines.txt
# driver_161_90frame/06031831_0913.MP4/02970.jpg
# driver_161_90frame/06031128_0818.MP4/04860.jpg
# driver_161_90frame/06040305_1061.MP4/04680.jpg
# driver_161_90frame/06032234_0971.MP4/02790.jpg
# driver_161_90frame/06040056_1018.MP4/02970.jpg
# driver_161_90frame/06031110_0812.MP4/03510.lines.txt
# driver_161_90frame/06031320_0848.MP4/01530.lines.txt
# driver_161_90frame/06031532_0853.MP4/00270.lines.txt
# driver_161_90frame/06031816_0908.MP4/01980.jpg
# driver_161_90frame/06031219_0835.MP4/02610.lines.txt
# driver_161_90frame/06032113_0944.MP4/04860.jpg
# driver_161_90frame/06040305_1061.MP4/02340.lines.txt
# driver_161_90frame/06040150_1036.MP4/04770.lines.txt
# driver_161_90frame/06040259_1059.MP4/03870.lines.txt
# driver_161_90frame/06032137_0952.MP4/02700.lines.txt
# driver_161_90frame/06040123_1027.MP4/00630.lines.txt
# driver_161_90frame/06031013_0793.MP4/00450.jpg
# driver_161_90frame/06031616_0868.MP4/04590.lines.txt
# driver_161_90frame/06030901_0769.MP4/00000.lines.txt
# driver_161_90frame/06031143_0823.MP4/03150.lines.txt
# driver_161_90frame/06031843_0917.MP4/02970.jpg
# driver_161_90frame/06031131_0819.MP4/01710.lines.txt
# driver_161_90frame/06032231_0970.MP4/03510.lines.txt
# driver_161_90frame/06032246_0975.MP4/02790.jpg
# driver_161_90frame/06032322_0987.MP4/04680.lines.txt
# driver_161_90frame/06031605_0864.MP4/01350.lines.txt
# driver_161_90frame/06030958_0788.MP4/03690.lines.txt
# driver_161_90frame/06032125_0948.MP4/04860.jpg
# driver_161_90frame/06031910_0926.MP4/00990.lines.txt
# driver_161_90frame/06040156_1038.MP4/00270.lines.txt
# driver_161_90frame/06031538_0855.MP4/05310.lines.txt
# driver_161_90frame/06032158_0959.MP4/00900.lines.txt
# driver_161_90frame/06040114_1024.MP4/04680.lines.txt
# driver_161_90frame/06032228_0969.MP4/04500.lines.txt
# driver_161_90frame/06031007_0791.MP4/04140.lines.txt
# driver_161_90frame/06031004_0790.MP4/01080.jpg
# driver_161_90frame/06031828_0912.MP4/02250.lines.txt
# driver_161_90frame/06032058_0939.MP4/04230.lines.txt
# driver_161_90frame/06031320_0848.MP4/04410.jpg
# driver_161_90frame/06031025_0797.MP4/00450.jpg
# driver_161_90frame/06031055_0807.MP4/00180.lines.txt
# driver_161_90frame/06040250_1056.MP4/01080.lines.txt
# driver_161_90frame/06032252_0977.MP4/01710.lines.txt
# driver_161_90frame/06040247_1055.MP4/00990.lines.txt
# driver_161_90frame/06031317_0847.MP4/01080.lines.txt
# driver_161_90frame/06032258_0979.MP4/02790.jpg
# driver_161_90frame/06032252_0977.MP4/04590.jpg
# driver_161_90frame/06030937_0781.MP4/04680.jpg
# driver_161_90frame/06032149_0956.MP4/04950.lines.txt
# driver_161_90frame/06040044_1014.MP4/01710.lines.txt
# driver_161_90frame/06032344_0994.MP4/01080.lines.txt
# driver_161_90frame/06031619_0869.MP4/02700.lines.txt
# driver_161_90frame/06031028_0798.MP4/02340.lines.txt
# driver_161_90frame/06031550_0859.MP4/00090.lines.txt
# driver_161_90frame/06031849_0919.MP4/00450.lines.txt
# driver_161_90frame/06040247_1055.MP4/02790.jpg
# driver_161_90frame/06031658_0882.MP4/02970.jpg
# driver_161_90frame/06031901_0923.MP4/04860.jpg
# driver_161_90frame/06031807_0905.MP4/04860.lines.txt
# driver_161_90frame/06032304_0981.MP4/04680.jpg
# driver_161_90frame/06040126_1028.MP4/04860.jpg
# driver_161_90frame/06031031_0799.MP4/02250.jpg
# driver_161_90frame/06031526_0851.MP4/02430.lines.txt
# driver_161_90frame/06031128_0818.MP4/01260.lines.txt
# driver_161_90frame/06031637_0875.MP4/03780.jpg
# driver_161_90frame/06031010_0792.MP4/03960.lines.txt
# driver_161_90frame/06032216_0965.MP4/01620.lines.txt
# driver_161_90frame/06030913_0773.MP4/01800.lines.txt
# driver_161_90frame/06031043_0803.MP4/00270.jpg
# driver_161_90frame/06032046_0935.MP4/01350.lines.txt
# driver_161_90frame/06031858_0922.MP4/04500.lines.txt
# driver_161_90frame/06031616_0868.MP4/04590.jpg
# driver_161_90frame/06030949_0785.MP4/04680.jpg
# driver_161_90frame/06031758_0902.MP4/05040.jpg
# driver_161_90frame/06031550_0859.MP4/00540.jpg
# driver_161_90frame/06031110_0812.MP4/02880.lines.txt
# driver_161_90frame/06031813_0907.MP4/02430.lines.txt
# driver_161_90frame/06031222_0836.MP4/02070.lines.txt
# driver_161_90frame/06040008_1002.MP4/01620.lines.txt
# driver_161_90frame/06040138_1032.MP4/04680.jpg
# driver_161_90frame/06031219_0835.MP4/01980.lines.txt
# driver_161_90frame/06032316_0985.MP4/04680.jpg
# driver_161_90frame/06031559_0862.MP4/02070.lines.txt
# driver_161_90frame/06040259_1059.MP4/02790.jpg
# driver_161_90frame/06032140_0953.MP4/02160.lines.txt
# driver_161_90frame/06031634_0874.MP4/03960.lines.txt
# driver_161_90frame/06031547_0858.MP4/00630.lines.txt
# driver_161_90frame/06031746_0898.MP4/03150.lines.txt
# driver_161_90frame/06031913_0927.MP4/04860.jpg
# driver_161_90frame/06040211_1043.MP4/03600.lines.txt
# driver_161_90frame/06032249_0976.MP4/01260.lines.txt
# driver_161_90frame/06030946_0784.MP4/01440.lines.txt
# driver_161_90frame/06031110_0812.MP4/01530.jpg
# driver_161_90frame/06031131_0819.MP4/00900.jpg
# driver_161_90frame/06031602_0863.MP4/00630.jpg
# driver_161_90frame/06040102_1020.MP4/02430.lines.txt
# driver_161_90frame/06031649_0879.MP4/03780.jpg
# driver_161_90frame/06040056_1018.MP4/03960.lines.txt
# driver_161_90frame/06031846_0918.MP4/02070.lines.txt
# driver_161_90frame/06032231_0970.MP4/02880.lines.txt
# driver_161_90frame/06031158_0828.MP4/03510.lines.txt
# driver_161_90frame/06031201_0829.MP4/04680.lines.txt
# driver_161_90frame/06031701_0883.MP4/00630.lines.txt
# driver_161_90frame/06031049_0805.MP4/02340.lines.txt
# driver_161_90frame/06040244_1054.MP4/03240.lines.txt
# driver_161_90frame/06031143_0823.MP4/00720.jpg
# driver_161_90frame/06031538_0855.MP4/04680.lines.txt
# driver_161_90frame/06030910_0772.MP4/03420.lines.txt
# driver_161_90frame/06040135_1031.MP4/02070.lines.txt
# driver_161_90frame/06030840_0762.MP4/00270.jpg
# driver_161_90frame/06032104_0941.MP4/02070.lines.txt
# driver_161_90frame/06032228_0969.MP4/03870.lines.txt
# driver_161_90frame/06031122_0816.MP4/01530.jpg
# driver_161_90frame/06031252_0846.MP4/04320.lines.txt
# driver_161_90frame/06031222_0836.MP4/00270.jpg
# driver_161_90frame/06032326_0988.MP4/01800.lines.txt
# driver_161_90frame/06031101_0809.MP4/02340.jpg
# driver_161_90frame/06031734_0894.MP4/00270.lines.txt
# driver_161_90frame/06031201_0829.MP4/01080.jpg
# driver_161_90frame/06031544_0857.MP4/02250.lines.txt
# driver_161_90frame/06031728_0892.MP4/04860.jpg
# driver_161_90frame/06030943_0783.MP4/03060.lines.txt
# driver_161_90frame/06031326_0850.MP4/02430.jpg
# driver_161_90frame/06030931_0779.MP4/01620.lines.txt
# driver_161_90frame/06031234_0840.MP4/00090.jpg
# driver_161_90frame/06030822_0756.MP4/00450.lines.txt
# driver_161_90frame/06040208_1042.MP4/03150.lines.txt
# driver_161_90frame/06032125_0948.MP4/00270.lines.txt
# driver_161_90frame/06031234_0840.MP4/03870.lines.txt
# driver_161_90frame/06030852_0766.MP4/00270.jpg
# driver_161_90frame/06031113_0813.MP4/02160.jpg
# driver_161_90frame/06031855_0921.MP4/02790.jpg
# driver_161_90frame/06032140_0953.MP4/00720.jpg
# driver_161_90frame/06040041_1013.MP4/00270.jpg
# driver_161_90frame/06040232_1050.MP4/00360.lines.txt
# driver_161_90frame/06031216_0834.MP4/04230.lines.txt
# driver_161_90frame/06030831_0759.MP4/01080.jpg
# driver_161_90frame/06031622_0870.MP4/01710.lines.txt
# driver_161_90frame/06030940_0782.MP4/00720.jpg
# driver_161_90frame/06031107_0811.MP4/03060.lines.txt
# driver_161_90frame/06032137_0952.MP4/04680.jpg
# driver_161_90frame/06032216_0965.MP4/00990.lines.txt
# driver_161_90frame/06040020_1006.MP4/01080.jpg
# driver_161_90frame/06032134_0951.MP4/04320.lines.txt
# driver_161_90frame/06030904_0770.MP4/00360.jpg
# driver_161_90frame/06031858_0922.MP4/03870.lines.txt
# driver_161_90frame/06031240_0842.MP4/01440.lines.txt
# driver_161_90frame/06030855_0767.MP4/00090.lines.txt
# driver_161_90frame/06040120_1026.MP4/02250.lines.txt
# driver_161_90frame/06040229_1049.MP4/01350.lines.txt
# driver_161_90frame/06040011_1003.MP4/01080.lines.txt
# driver_161_90frame/06040008_1002.MP4/00990.lines.txt
# driver_161_90frame/06031140_0822.MP4/03150.jpg
# driver_161_90frame/06031655_0881.MP4/01350.lines.txt
# driver_161_90frame/06031317_0847.MP4/03240.jpg
# driver_161_90frame/06031016_0794.MP4/01080.jpg
# driver_161_90frame/06040211_1043.MP4/02970.lines.txt
# driver_161_90frame/06032149_0956.MP4/04680.jpg
# driver_161_90frame/06031925_0931.MP4/00540.lines.txt
# driver_161_90frame/06032155_0958.MP4/02520.lines.txt
# driver_161_90frame/06030852_0766.MP4/02700.lines.txt
# driver_161_90frame/06030952_0786.MP4/00720.jpg
# driver_161_90frame/06031755_0901.MP4/00270.lines.txt
# driver_161_90frame/06031213_0833.MP4/02610.jpg
# driver_161_90frame/06030837_0761.MP4/00000.lines.txt
# driver_161_90frame/06030928_0778.MP4/01170.lines.txt
# driver_161_90frame/06040141_1033.MP4/00720.jpg
# driver_161_90frame/06030910_0772.MP4/02160.jpg
# driver_161_90frame/06031204_0830.MP4/01350.lines.txt
# driver_161_90frame/06030931_0779.MP4/01530.jpg
# driver_161_90frame/06040120_1026.MP4/01530.jpg
# driver_161_90frame/06031137_0821.MP4/05310.lines.txt
# driver_161_90frame/06031532_0853.MP4/00000.lines.txt
# driver_161_90frame/06040220_1046.MP4/00270.jpg
# driver_161_90frame/06031728_0892.MP4/02430.lines.txt
# driver_161_90frame/06030910_0772.MP4/02790.lines.txt
# driver_161_90frame/06031631_0873.MP4/00450.jpg
# driver_161_90frame/06040150_1036.MP4/04500.lines.txt
# driver_161_90frame/06031028_0798.MP4/01080.jpg
# driver_161_90frame/06031323_0849.MP4/05040.jpg
# driver_161_90frame/06040259_1059.MP4/03600.lines.txt
# driver_161_90frame/06031240_0842.MP4/03600.jpg
# driver_161_90frame/06040041_1013.MP4/03330.lines.txt
# driver_161_90frame/06031252_0846.MP4/03690.lines.txt
# driver_161_90frame/06031610_0866.MP4/01260.jpg
# driver_161_90frame/06031616_0868.MP4/04320.lines.txt
# driver_161_90frame/06032119_0946.MP4/02430.lines.txt
# driver_161_90frame/06031055_0807.MP4/00270.jpg
# driver_161_90frame/06040232_1050.MP4/00090.jpg
# driver_161_90frame/06030922_0776.MP4/02160.jpg

# %%
import os
import pickle
import cv2
import numpy as np
import torch
from torch.utils.data import Dataset, DataLoader

# %%
os.listdir('drive/MyDrive/LaneDetection') #Check if you have all the files
# Out:
# ['CUDatamap.pkl',
#  'CUDatamap_stline2.pkl',
#  'CUDatamap_line2.pkl',
#  'CUDatamap_coef.pkl',
#  'vgg16.pt',
#  'model_confidence.pt',
#  '.ipynb_checkpoints',
#  'model_1.pt']

# %%
with open("drive/MyDrive/LaneDetection/CUDatamap_line2.pkl","rb") as f:
    data_line_map = pickle.load(f)
with open("drive/MyDrive/LaneDetection/CUDatamap_stline2.pkl","rb") as f:
    data_stline_map = pickle.load(f)

# %%
y_col = np.linspace(400,580,19)

class LaneDataset(Dataset):
    """Face Landmarks dataset."""

    def __init__(self, data_line_map,data_stline_map,scale=None,reg_scale=10):

        self.new_data_keys = list(data_line_map.keys())
        self.data_line_map = data_line_map
        self.data_stline_map = data_stline_map
        self.scale = scale
        image_loc = self.new_data_keys[0]
        image = cv2.imread(image_loc)
        height,width,channel = image.shape
        self.height = height
        self.width = width
        self.reg_scale = reg_scale




    def __len__(self):
        return len(self.new_data_keys)




    def get_lane_angle(self,myline):
        global y_col #its actually row
        row = y_col[-1]
        col = myline[-1]

        new_col = col - self.width//2
        new_row = row + self.height

        angle = -np.arctan2(new_col,new_row)
        # if angle<0:
        #     angle = 2*np.pi+angle

        return angle

    def get_lane_bins(self,stline):
        angle = self.get_lane_angle(stline)
        angle = np.clip(angle,-1,1)
        mybin = int(round(angle/0.125))+8 #17 bins -1 to 1 as 0 to 17

        return mybin,angle


    def get_regression_confidence_mat(self,stlines,lines):
        regression_mat = np.zeros((19,17),dtype=np.float32) #19 rows and 17 for 17 bins
        confidence_mat = np.zeros((17,),dtype=np.float32)
        for stline,line in zip(stlines,lines):
            mybin,angle = self.get_lane_bins(stline=stline)
            regression_mat[:,mybin] = line
            confidence_mat[mybin] = 1
        return regression_mat.flatten(),confidence_mat

    def __getitem__(self, idx):
        if torch.is_tensor(idx):
            idx = idx.tolist()
        image_loc = self.new_data_keys[idx]
        lines = self.data_line_map[image_loc] #Since
        image = cv2.imread(image_loc)

        if self.scale is not None:
            image = cv2.resize(image,self.scale)

        stlines = self.data_stline_map[image_loc]


        #visualize_bundle = (image,lines,stlines,idx) #use only for visualization


        image_tensor = torch.tensor(image,dtype=torch.float32)/255 #convert to tensor and normalise
        image_tensor2 = image_tensor.permute(2,0,1) #bring the channel to front

        regression_mat,confidence_mat  = self.get_regression_confidence_mat(stlines,lines)
        regression_mat_tensor = torch.tensor(regression_mat,dtype=torch.float32)
        regression_mat_tensor = torch.clip(regression_mat_tensor,-1500,2500)/self.reg_scale #Clip and also reduce the scale
        confidence_mat_tensor = torch.tensor(confidence_mat,dtype=torch.float32)

        #print(image_loc,sum(regression_mat))


        return image_tensor2,regression_mat_tensor,confidence_mat_tensor

# %%
import torch.nn as nn
import torchvision.models as models
from torch.nn import functional as F

# %%
vgg16 = models.vgg16(pretrained=True)
for param in vgg16.parameters():
            param.requires_grad = False #Disable the vgg trainings
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/vgg16-397923af.pth" to /root/.cache/torch/hub/checkpoints/vgg16-397923af.pth
# 100%|██████████| 528M/528M [00:05<00:00, 98.8MB/s]

# %%
class VGGBlock(nn.Module):
    def __init__(self):
        super(VGGBlock, self).__init__()
        self.block1 = nn.Sequential(*list(vgg16.features.children())[:5])
        self.block1t4 = nn.Sequential(*list(vgg16.features.children())[5:16])  # Block 4 of VGG16

    def forward(self, x):
      x1_b = self.block1(x)  # Output will be of shape (b, 64, 112, 112)
      x2 = self.block1t4(x1_b)  # Output will be of shape (b, 256, 56, 56)
      return x1_b,x2


class UpSampleNeck(nn.Module):
    def __init__(self):
        super(UpSampleNeck, self).__init__()
        # Trainable 3x3 convolution to reduce features from 64 to 32
        self.conv3x3_1 = nn.Conv2d(in_channels=64, out_channels=32, kernel_size=3, stride=1, padding=1)
        self.bn1 = nn.BatchNorm2d(32)  # BatchNorm after first conv

        # Reduce Block 4 features from 256 to 128
        self.reduce_conv_block4 = nn.Conv2d(in_channels=256, out_channels=128, kernel_size=3, stride=1, padding=1)
        self.bn2 = nn.BatchNorm2d(128)  # BatchNorm after Block 4 reduction

        # Upsample
        self.upconv = nn.ConvTranspose2d(in_channels=128, out_channels=64, kernel_size=4, stride=2, padding=1)
        self.bn3 = nn.BatchNorm2d(64)  # BatchNorm after upconv

        # Convolution layers after concatenation
        self.conv3x3_2 = nn.Conv2d(in_channels=96, out_channels=128, kernel_size=3, stride=1, padding=1)
        self.bn4 = nn.BatchNorm2d(128)  # BatchNorm after concat
        self.avg_pool_2 = nn.AvgPool2d(kernel_size=2, stride=2)


    def forward(self,x1_b,x2):
        # Pass through the 3x3 convolution layer, batch norm, and ReLU
        x1 = self.conv3x3_1(x1_b)  # Output will be of shape (b, 32, 112, 112)
        x1 = self.bn1(x1)
        x1 = F.relu(x1)

        # Block 4 forward pass (without max-pooling)
        x2 = self.reduce_conv_block4(x2)
        x2 = self.bn2(x2)
        x2 = self.upconv(x2)  # Output will be of shape (b, 64, 112, 112)
        x2 = self.bn3(x2)
        x2 = F.relu(x2)

        # Concatenate x1 and x2 along the channel dimension
        x_concat = torch.cat((x1, x2), dim=1)  # Output will be of shape (b, 96, 112, 112)

        # Convolution layer after concatenation
        x3 = self.conv3x3_2(x_concat)
        x3 = self.bn4(x3)
        x3 = self.avg_pool_2(x3)  # Output will be of shape (b, 128, 56, 56)

        x5 = F.relu(x3) #Will be also used for confidence calculation

        return x5,x_concat


class LaneConfidenceHead(nn.Module):
    def __init__(self):
        super(LaneConfidenceHead, self).__init__()

        self.conv3x3_9 = nn.Conv2d(in_channels=128,out_channels=256,kernel_size=3,stride=1)
        self.bn11 = nn.BatchNorm2d(256)
        self.maxpool_5 = nn.MaxPool2d(kernel_size=3,stride=3)

        self.conv3x3_10 = nn.Conv2d(in_channels=256,out_channels=64,kernel_size=1,stride=1)
        self.bn12 = nn.BatchNorm2d(64)
        #self.maxpool_6 = nn.MaxPool2d(kernel_size=3,stride=3)

        self.conv3x3_11 = nn.Conv2d(in_channels=64,out_channels=8,kernel_size=1,stride=1)
        self.bn13 = nn.BatchNorm2d(8)
        #self.maxpool_7 = nn.MaxPool2d(kernel_size=3,stride=3)




        self.Linear_c1 = nn.Linear(in_features=2592,out_features=256)
        self.Linear_c2 = nn.Linear(in_features=256,out_features=17)

        self.flatten = nn.Flatten()


    def forward(self,x5):


      x5 = self.conv3x3_9(x5)
      x5 = self.bn11(x5)
      x5 = self.maxpool_5(x5)
      x5 = F.relu(x5)



      x5 = self.conv3x3_10(x5)
      x5 = self.bn12(x5)
      #x5 = self.maxpool_6(x5)
      x5 = F.relu(x5)



      x5 = self.conv3x3_11(x5)
      x5 = self.bn13(x5)

      #x5 = self.maxpool_7(x5)
      x5 = F.relu(x5)

      x5 = self.flatten(x5)



      x5 = self.Linear_c1(x5)
      x5 = F.sigmoid(x5)
      x5 = self.Linear_c2(x5)


      return x5

# Add positional encoding
class PositionalEncoding(nn.Module):
    def __init__(self,device, d_model, max_len=256):
        super(PositionalEncoding, self).__init__()
        self.encoding = torch.zeros(max_len, d_model)
        position = torch.arange(0, max_len).unsqueeze(1).float()
        div_term = torch.exp(torch.arange(0, d_model, 2).float() * -(torch.log(torch.tensor(10000.0)) / d_model))
        self.encoding[:, 0::2] = torch.sin(position * div_term)
        self.encoding[:, 1::2] = torch.cos(position * div_term)
        self.encoding = self.encoding.unsqueeze(0)  # Add batch dimension
        self.encoding = self.encoding.to(device)




    def forward(self, x):

        return x + self.encoding[:, :x.size(1)]


class Regression_Head(nn.Module):
    def __init__(self,device):
        super(Regression_Head, self).__init__()
        self.conv3x3_12 = nn.Conv2d(in_channels=96,out_channels=12,kernel_size=1,stride=1,padding=1)
        # Patch extraction using unfold
        self.patch_size = 7
        self.unfold = nn.Unfold(kernel_size=self.patch_size, stride=self.patch_size)
        self.fold = nn.Fold(output_size=(112, 112), kernel_size=self.patch_size, stride=self.patch_size)
        num_patches = 256  # Number of patches
        embedding_dim = 588  # Each patch dimension
        channels = 12
        self.patch_embedding_layer = nn.Linear(embedding_dim, embedding_dim)

        self.positional_encoding = PositionalEncoding(device,embedding_dim, max_len=num_patches)

        # Define multi-head attention layer
        num_heads = 2
        self.attention_layer = nn.MultiheadAttention(embed_dim=embedding_dim, num_heads=num_heads, dropout=0.1)


        self.Conv2d_13 = nn.Conv2d(in_channels=12,out_channels=6,kernel_size=2,stride=2)
        self.bn_14 = nn.BatchNorm2d(6)
        self.Conv2d_15 = nn.Conv2d(in_channels=6,out_channels=2,kernel_size=2,stride=2)
        self.bn_16 = nn.BatchNorm2d(2)

        self.flatten = nn.Flatten()
        self.linear_final = nn.Linear(in_features=1568,out_features=512)
        self.linear_final2 = nn.Linear(in_features=512,out_features=19*17)




    def forward(self,x_concat):
        x6 = self.conv3x3_12(x_concat)
        x6 = F.relu(x6)

        patches = self.unfold(x6) # Shape: [batch_size,channels * patch_size * patch_size, num_patches]
        #batch_size = patches.size(0)
        #channels = patches.size(1)
        #print(patches.shape)
        patches = patches.permute(0, 2,1)

        patches = self.patch_embedding_layer(patches)
        #print("After Patch Embedding",patches.shape)
        patches = self.positional_encoding(patches)
        #print("After Patch Embedding",patches.shape)

        # Apply multi-head attention
        attention_output, _ = self.attention_layer(patches, patches, patches)
        #print("After Attention",attention_output.shape)

        # Fold the attention output back to the original image size
        attention_output = attention_output.permute(0, 2, 1)
        transformed_feature_map = self.fold(attention_output)
        #print("After Fold",transformed_feature_map.shape)

        conv_out = self.Conv2d_13(transformed_feature_map)
        conv_out = self.bn_14(conv_out)
        cov_out = F.relu(conv_out)

        conv_out = self.Conv2d_15(cov_out)
        conv_out = self.bn_16(conv_out)
        conv_out = F.relu(conv_out)

        conv_out = self.flatten(conv_out)
        conv_out = self.linear_final(conv_out)
        conv_out = F.relu(conv_out)
        conv_out = self.linear_final2(conv_out)

        return conv_out

# %%
class LaneDetection_2(nn.Module):
    def __init__(self,device):
        super(LaneDetection_2, self).__init__()

        self.vggblock = VGGBlock()
        self.upsample_neck = UpSampleNeck()
        self.laneconfidence_head = LaneConfidenceHead()

        self.regression_head = Regression_Head(device)





    def forward(self, x):
        # Block 1 forward pass
        x1_b,x2 = self.vggblock(x)

        x5,x_concat = self.upsample_neck(x1_b,x2)

        #print(x5.shape,x_concat.shape)

        x6 = self.laneconfidence_head(x5)

        x7 = self.regression_head(x_concat)

        return x6,x7

# %%
class LaneLoss(nn.Module):
    def __init__(self):
        super(LaneLoss, self).__init__()
        self.regression_loss_fn = nn.MSELoss(reduction='none')  # Use 'none' to calculate loss per sample
        self.confidence_loss_fn = nn.BCEWithLogitsLoss()  # Applies a logistic loss to the confidence scores

    # def forward(self, regression_pred, regression_target, confidence_pred, confidence_target): #Ignore this for now
    #     # Regression loss where confidence is 1
    #     regression_pred = regression_pred.view(-1, 19, 17)
    #     regression_target = regression_target.view(-1, 19, 17)

    #     #print(regression_pred.shape)

    #     # Apply confidence target to each column of the regression output
    #     confidence_target_expanded = confidence_target.unsqueeze(1).expand_as(regression_pred)
    #     #print(confidence_target_expanded)
    #     regression_loss = self.regression_loss_fn(regression_pred, regression_target)  # Shape: [batch_size, 19, 17]
    #     regression_loss = (regression_loss * confidence_target_expanded).mean()

    #     # Confidence loss (logistic loss)
    #     confidence_loss = self.confidence_loss_fn(confidence_pred, confidence_target)

    #     # Combine the losses
    #     total_loss = regression_loss + confidence_loss

    #     return total_loss


    def forward(self, regression_pred, regression_target, confidence_pred, confidence_target):
        # # Regression loss where confidence is 1
        # regression_pred = regression_pred.view(-1, 19, 17)
        # regression_target = regression_target.view(-1, 19, 17)

        # #print(regression_pred.shape)

        # # Apply confidence target to each column of the regression output
        # confidence_target_expanded = confidence_target.unsqueeze(1).expand_as(regression_pred)
        # #print(confidence_target_expanded)
        # regression_loss = self.regression_loss_fn(regression_pred, regression_target)  # Shape: [batch_size, 19, 17]
        # regression_loss = (regression_loss * confidence_target_expanded).mean()

        # Confidence loss (logistic loss)
        confidence_loss = self.confidence_loss_fn(confidence_pred, confidence_target)

        # Combine the losses
        total_loss = confidence_loss

        return total_loss

class LaneCondidenceLoss(nn.Module):
    def __init__(self):
        super(LaneCondidenceLoss, self).__init__()
        self.confidence_loss_fn = nn.BCEWithLogitsLoss()  # Applies a logistic loss to the confidence scores

    def forward(self, confidence_pred, confidence_target):
        confidence_loss = self.confidence_loss_fn(confidence_pred, confidence_target)
        return confidence_loss

# %% [markdown]
# #### Training starts below

# %%
import torch.optim as optim
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = LaneDetection_2(device)

model = model.to(device)
loss_fn = LaneCondidenceLoss()
lane_dataset = LaneDataset(data_line_map=data_line_map,data_stline_map=data_stline_map,scale=(224,224))
dataloader = DataLoader(lane_dataset, batch_size=32,shuffle=True)
# Initialize the optimizer
optimizer = optim.Adam(model.parameters(), lr=0.001)
num_epochs = 10  # Adjust the number of epochs as needed

# %%
total_params = sum(p.numel() for p in model.parameters())
print(f"Number of parameters in million: {total_params/1000000}")
# Out:
# Number of parameters in million: 5.974732

# %%
device
# Out:
# device(type='cuda')

# %%
for param in model.vggblock.parameters():
            param.requires_grad = False #Disable the vgg trainings

for param in model.upsample_neck.parameters():
            param.requires_grad = True #Enable for neck

for param in model.laneconfidence_head.parameters():
            param.requires_grad = True #Enable for neck

for param in model.regression_head.parameters():
            param.requires_grad = False #Disable the regression head for now as we are not going to train it

# %%
import time

for epoch in range(num_epochs):
    model.train()  # Set the model to training mode
    running_loss = 0.0
    #print("Start",time.time())
    for batch_idx, (images, regression_targets, confidence_targets) in enumerate(dataloader):
        images = images.to(device)
        # max_lane_dis = max(max_lane_dis,regression_targets.max())
        # min_lane_dis = min(min_lane_dis,regression_targets.min())
        #print("Data fetched",time.time()
        regression_targets = regression_targets.to(device)
        confidence_targets = confidence_targets.to(device)
        #print("Datafetched",time.time())
        # Zero the parameter gradients
        optimizer.zero_grad()

        # Forward pass

        confidence_pred,regression_pred = model(images)

        # Calculate loss
        loss = loss_fn(confidence_pred, confidence_targets)

        # Backward pass and optimize
        loss.backward()
        optimizer.step()

        # Update running loss
        running_loss += loss.item()

        # Print progress
        if batch_idx % 20 == 0:
            print(f'Epoch [{epoch+1}/{num_epochs}], Batch [{batch_idx+1}/{len(dataloader)}], Loss: {loss.item():.4f}')
            torch.save(model,"drive/MyDrive/LaneDetection/model_1.pt")
        #print("Model stepped",time.time())
    # Print epoch loss
    print(f'Epoch [{epoch+1}/{num_epochs}], Loss: {running_loss/len(dataloader):.4f}')

print("Training completed.")
# Out:
# Epoch [1/10], Batch [1/507], Loss: 0.6704
# Epoch [1/10], Batch [21/507], Loss: 0.3751
# Epoch [1/10], Batch [41/507], Loss: 0.3523
# Epoch [1/10], Batch [61/507], Loss: 0.3427
# Epoch [1/10], Batch [81/507], Loss: 0.3305
# Epoch [1/10], Batch [101/507], Loss: 0.3092
# Epoch [1/10], Batch [121/507], Loss: 0.3041
# Epoch [1/10], Batch [141/507], Loss: 0.3204
# Epoch [1/10], Batch [161/507], Loss: 0.2876
# Epoch [1/10], Batch [181/507], Loss: 0.2518
# Epoch [1/10], Batch [201/507], Loss: 0.2299
# Epoch [1/10], Batch [221/507], Loss: 0.2212
# Epoch [1/10], Batch [241/507], Loss: 0.2578
# Epoch [1/10], Batch [261/507], Loss: 0.2380
# Epoch [1/10], Batch [281/507], Loss: 0.2076
# Epoch [1/10], Batch [301/507], Loss: 0.2102
# Epoch [1/10], Batch [321/507], Loss: 0.2011
# Epoch [1/10], Batch [341/507], Loss: 0.1842
# Epoch [1/10], Batch [361/507], Loss: 0.2333
# Epoch [1/10], Batch [381/507], Loss: 0.2708
# Epoch [1/10], Batch [401/507], Loss: 0.2341
# Epoch [1/10], Batch [421/507], Loss: 0.1999
# Epoch [1/10], Batch [441/507], Loss: 0.2384
# Epoch [1/10], Batch [461/507], Loss: 0.2433
# Epoch [1/10], Batch [481/507], Loss: 0.1508
# Epoch [1/10], Batch [501/507], Loss: 0.1879
# Epoch [1/10], Loss: 0.2535
# Epoch [2/10], Batch [1/507], Loss: 0.1007
# Epoch [2/10], Batch [21/507], Loss: 0.1602
# Epoch [2/10], Batch [41/507], Loss: 0.1646
# Epoch [2/10], Batch [61/507], Loss: 0.1930
# Epoch [2/10], Batch [81/507], Loss: 0.1698
# Epoch [2/10], Batch [101/507], Loss: 0.1671
# Epoch [2/10], Batch [121/507], Loss: 0.1978
# Epoch [2/10], Batch [141/507], Loss: 0.1756
# Epoch [2/10], Batch [161/507], Loss: 0.2256
# Epoch [2/10], Batch [181/507], Loss: 0.1369
# Epoch [2/10], Batch [201/507], Loss: 0.1405
# Epoch [2/10], Batch [221/507], Loss: 0.1926
# Epoch [2/10], Batch [241/507], Loss: 0.1546
# Epoch [2/10], Batch [261/507], Loss: 0.2366
# Epoch [2/10], Batch [281/507], Loss: 0.1349
# Epoch [2/10], Batch [301/507], Loss: 0.1721
# Epoch [2/10], Batch [321/507], Loss: 0.1087
# Epoch [2/10], Batch [341/507], Loss: 0.1981
# Epoch [2/10], Batch [361/507], Loss: 0.1527
# Epoch [2/10], Batch [381/507], Loss: 0.1260
# Epoch [2/10], Batch [401/507], Loss: 0.1530
# Epoch [2/10], Batch [421/507], Loss: 0.1738
# Epoch [2/10], Batch [441/507], Loss: 0.1564
# Epoch [2/10], Batch [461/507], Loss: 0.1260
# Epoch [2/10], Batch [481/507], Loss: 0.1312
# Epoch [2/10], Batch [501/507], Loss: 0.2002
# Epoch [2/10], Loss: 0.1705
# Epoch [3/10], Batch [1/507], Loss: 0.1114
# Epoch [3/10], Batch [21/507], Loss: 0.1772
# Epoch [3/10], Batch [41/507], Loss: 0.1496
# Epoch [3/10], Batch [61/507], Loss: 0.1638
# Epoch [3/10], Batch [81/507], Loss: 0.0992
# Epoch [3/10], Batch [101/507], Loss: 0.1430
# Epoch [3/10], Batch [121/507], Loss: 0.1125
# Epoch [3/10], Batch [141/507], Loss: 0.1117
# Epoch [3/10], Batch [161/507], Loss: 0.0993
# Epoch [3/10], Batch [181/507], Loss: 0.1522
# Epoch [3/10], Batch [201/507], Loss: 0.1314
# Epoch [3/10], Batch [221/507], Loss: 0.1590
# Epoch [3/10], Batch [241/507], Loss: 0.1676
# Epoch [3/10], Batch [261/507], Loss: 0.1201
# Epoch [3/10], Batch [281/507], Loss: 0.1453
# Epoch [3/10], Batch [301/507], Loss: 0.1603
# Epoch [3/10], Batch [321/507], Loss: 0.0970
# Epoch [3/10], Batch [341/507], Loss: 0.1125
# Epoch [3/10], Batch [361/507], Loss: 0.1208
# Epoch [3/10], Batch [381/507], Loss: 0.1472
# Epoch [3/10], Batch [401/507], Loss: 0.0885
# Epoch [3/10], Batch [421/507], Loss: 0.1073
# Epoch [3/10], Batch [441/507], Loss: 0.1648
# Epoch [3/10], Batch [461/507], Loss: 0.1157
# Epoch [3/10], Batch [481/507], Loss: 0.1150
# Epoch [3/10], Batch [501/507], Loss: 0.1588
# Epoch [3/10], Loss: 0.1381
# Epoch [4/10], Batch [1/507], Loss: 0.0972
# Epoch [4/10], Batch [21/507], Loss: 0.1179
# Epoch [4/10], Batch [41/507], Loss: 0.0913
# Epoch [4/10], Batch [61/507], Loss: 0.1087
# Epoch [4/10], Batch [81/507], Loss: 0.0680
# Epoch [4/10], Batch [101/507], Loss: 0.1317
# Epoch [4/10], Batch [121/507], Loss: 0.1101
# Epoch [4/10], Batch [141/507], Loss: 0.0930
# Epoch [4/10], Batch [161/507], Loss: 0.0983
# Epoch [4/10], Batch [181/507], Loss: 0.1033
# Epoch [4/10], Batch [201/507], Loss: 0.0845
# Epoch [4/10], Batch [221/507], Loss: 0.1316
# Epoch [4/10], Batch [241/507], Loss: 0.0851
# Epoch [4/10], Batch [261/507], Loss: 0.0918
# Epoch [4/10], Batch [281/507], Loss: 0.1343
# Epoch [4/10], Batch [301/507], Loss: 0.1109
# Epoch [4/10], Batch [321/507], Loss: 0.0909
# Epoch [4/10], Batch [341/507], Loss: 0.0805
# Epoch [4/10], Batch [361/507], Loss: 0.1117
# Epoch [4/10], Batch [381/507], Loss: 0.0964
# Epoch [4/10], Batch [401/507], Loss: 0.0871
# Epoch [4/10], Batch [421/507], Loss: 0.1383
# Epoch [4/10], Batch [441/507], Loss: 0.1196
# Epoch [4/10], Batch [461/507], Loss: 0.1634
# Epoch [4/10], Batch [481/507], Loss: 0.1063
# Epoch [4/10], Batch [501/507], Loss: 0.0939
# Epoch [4/10], Loss: 0.1118
# Epoch [5/10], Batch [1/507], Loss: 0.0954
# Epoch [5/10], Batch [21/507], Loss: 0.0942
# Epoch [5/10], Batch [41/507], Loss: 0.0655
# Epoch [5/10], Batch [61/507], Loss: 0.0660
# Epoch [5/10], Batch [81/507], Loss: 0.0703
# Epoch [5/10], Batch [101/507], Loss: 0.1179
# Epoch [5/10], Batch [121/507], Loss: 0.0856
# Epoch [5/10], Batch [141/507], Loss: 0.1072
# Epoch [5/10], Batch [161/507], Loss: 0.0588
# Epoch [5/10], Batch [181/507], Loss: 0.1187
# Epoch [5/10], Batch [201/507], Loss: 0.0925
# Epoch [5/10], Batch [221/507], Loss: 0.0961
# Epoch [5/10], Batch [241/507], Loss: 0.0696
# Epoch [5/10], Batch [261/507], Loss: 0.0991
# Epoch [5/10], Batch [281/507], Loss: 0.0884
# Epoch [5/10], Batch [301/507], Loss: 0.1021
# Epoch [5/10], Batch [321/507], Loss: 0.0671
# Epoch [5/10], Batch [341/507], Loss: 0.0703
# Epoch [5/10], Batch [361/507], Loss: 0.0948
# Epoch [5/10], Batch [381/507], Loss: 0.1127
# Epoch [5/10], Batch [401/507], Loss: 0.0751
# Epoch [5/10], Batch [421/507], Loss: 0.1084
# Epoch [5/10], Batch [441/507], Loss: 0.0957
# Epoch [5/10], Batch [461/507], Loss: 0.0925
# Epoch [5/10], Batch [481/507], Loss: 0.0991
# Epoch [5/10], Batch [501/507], Loss: 0.1348
# Epoch [5/10], Loss: 0.0882
# Epoch [6/10], Batch [1/507], Loss: 0.0664
# Epoch [6/10], Batch [21/507], Loss: 0.0620
# Epoch [6/10], Batch [41/507], Loss: 0.0923
# Epoch [6/10], Batch [61/507], Loss: 0.0912
# Epoch [6/10], Batch [81/507], Loss: 0.0750
# Epoch [6/10], Batch [101/507], Loss: 0.0794
# Epoch [6/10], Batch [121/507], Loss: 0.0668
# Epoch [6/10], Batch [141/507], Loss: 0.0642
# Epoch [6/10], Batch [161/507], Loss: 0.0570
# Epoch [6/10], Batch [181/507], Loss: 0.0762
# Epoch [6/10], Batch [201/507], Loss: 0.0820
# Epoch [6/10], Batch [221/507], Loss: 0.0613
# Epoch [6/10], Batch [241/507], Loss: 0.0683
# Epoch [6/10], Batch [261/507], Loss: 0.0462
# Epoch [6/10], Batch [281/507], Loss: 0.0515
# Epoch [6/10], Batch [301/507], Loss: 0.0520
# Epoch [6/10], Batch [321/507], Loss: 0.0817
# Epoch [6/10], Batch [341/507], Loss: 0.0681
# Epoch [6/10], Batch [361/507], Loss: 0.0587
# Epoch [6/10], Batch [381/507], Loss: 0.1059
# Epoch [6/10], Batch [401/507], Loss: 0.0769
# Epoch [6/10], Batch [421/507], Loss: 0.0691
# Epoch [6/10], Batch [441/507], Loss: 0.0591
# Epoch [6/10], Batch [461/507], Loss: 0.0761
# Epoch [6/10], Batch [481/507], Loss: 0.1099
# Epoch [6/10], Batch [501/507], Loss: 0.0395
# Epoch [6/10], Loss: 0.0662
# Epoch [7/10], Batch [1/507], Loss: 0.0458
# Epoch [7/10], Batch [21/507], Loss: 0.0710
# Epoch [7/10], Batch [41/507], Loss: 0.0436
# Epoch [7/10], Batch [61/507], Loss: 0.0408
# Epoch [7/10], Batch [81/507], Loss: 0.0372
# Epoch [7/10], Batch [101/507], Loss: 0.0372
# Epoch [7/10], Batch [121/507], Loss: 0.0506
# Epoch [7/10], Batch [141/507], Loss: 0.0523
# Epoch [7/10], Batch [161/507], Loss: 0.0628
# Epoch [7/10], Batch [181/507], Loss: 0.0386
# Epoch [7/10], Batch [201/507], Loss: 0.0569
# Epoch [7/10], Batch [221/507], Loss: 0.0795
# Epoch [7/10], Batch [241/507], Loss: 0.0467
# Epoch [7/10], Batch [261/507], Loss: 0.0694
# Epoch [7/10], Batch [281/507], Loss: 0.0629
# Epoch [7/10], Batch [301/507], Loss: 0.0676
# Epoch [7/10], Batch [321/507], Loss: 0.0455
# Epoch [7/10], Batch [341/507], Loss: 0.0393
# Epoch [7/10], Batch [361/507], Loss: 0.0441
# Epoch [7/10], Batch [381/507], Loss: 0.0281
# Epoch [7/10], Batch [401/507], Loss: 0.0619
# Epoch [7/10], Batch [421/507], Loss: 0.0434
# Epoch [7/10], Batch [441/507], Loss: 0.0460
# Epoch [7/10], Batch [461/507], Loss: 0.0499
# Epoch [7/10], Batch [481/507], Loss: 0.0665
# Epoch [7/10], Batch [501/507], Loss: 0.0655
# Epoch [7/10], Loss: 0.0471
# Epoch [8/10], Batch [1/507], Loss: 0.0173
# Epoch [8/10], Batch [21/507], Loss: 0.0394
# Epoch [8/10], Batch [41/507], Loss: 0.0422
# Epoch [8/10], Batch [61/507], Loss: 0.0292
# Epoch [8/10], Batch [81/507], Loss: 0.0316
# Epoch [8/10], Batch [101/507], Loss: 0.0319
# Epoch [8/10], Batch [121/507], Loss: 0.0304
# Epoch [8/10], Batch [141/507], Loss: 0.0238
# Epoch [8/10], Batch [161/507], Loss: 0.0340
# Epoch [8/10], Batch [181/507], Loss: 0.0209
# Epoch [8/10], Batch [201/507], Loss: 0.0173
# Epoch [8/10], Batch [221/507], Loss: 0.0172
# Epoch [8/10], Batch [241/507], Loss: 0.0236
# Epoch [8/10], Batch [261/507], Loss: 0.0241
# Epoch [8/10], Batch [281/507], Loss: 0.0344
# Epoch [8/10], Batch [301/507], Loss: 0.0303
# Epoch [8/10], Batch [321/507], Loss: 0.0535
# Epoch [8/10], Batch [341/507], Loss: 0.0312
# Epoch [8/10], Batch [361/507], Loss: 0.0410
# Epoch [8/10], Batch [381/507], Loss: 0.0283
# Epoch [8/10], Batch [401/507], Loss: 0.0451
# Epoch [8/10], Batch [421/507], Loss: 0.0235
# Epoch [8/10], Batch [441/507], Loss: 0.0173
# Epoch [8/10], Batch [461/507], Loss: 0.0306
# Epoch [8/10], Batch [481/507], Loss: 0.0192
# Epoch [8/10], Batch [501/507], Loss: 0.0239
# Epoch [8/10], Loss: 0.0319
# Epoch [9/10], Batch [1/507], Loss: 0.0137
# Epoch [9/10], Batch [21/507], Loss: 0.0233
# Epoch [9/10], Batch [41/507], Loss: 0.0321
# Epoch [9/10], Batch [61/507], Loss: 0.0193
# Epoch [9/10], Batch [81/507], Loss: 0.0217
# Epoch [9/10], Batch [101/507], Loss: 0.0231
# Epoch [9/10], Batch [121/507], Loss: 0.0218
# Epoch [9/10], Batch [141/507], Loss: 0.0282
# Epoch [9/10], Batch [161/507], Loss: 0.0189
# Epoch [9/10], Batch [181/507], Loss: 0.0265
# Epoch [9/10], Batch [201/507], Loss: 0.0119
# Epoch [9/10], Batch [221/507], Loss: 0.0229
# Epoch [9/10], Batch [241/507], Loss: 0.0264
# Epoch [9/10], Batch [261/507], Loss: 0.0104
# Epoch [9/10], Batch [281/507], Loss: 0.0254
# Epoch [9/10], Batch [301/507], Loss: 0.0173
# Epoch [9/10], Batch [321/507], Loss: 0.0205
# Epoch [9/10], Batch [341/507], Loss: 0.0322
# Epoch [9/10], Batch [361/507], Loss: 0.0453
# Epoch [9/10], Batch [381/507], Loss: 0.0355
# Epoch [9/10], Batch [401/507], Loss: 0.0314
# Epoch [9/10], Batch [421/507], Loss: 0.0307
# Epoch [9/10], Batch [441/507], Loss: 0.0299
# Epoch [9/10], Batch [461/507], Loss: 0.0364
# Epoch [9/10], Batch [481/507], Loss: 0.0174
# Epoch [9/10], Batch [501/507], Loss: 0.0236
# Epoch [9/10], Loss: 0.0219
# Epoch [10/10], Batch [1/507], Loss: 0.0139
# Epoch [10/10], Batch [21/507], Loss: 0.0083
# Epoch [10/10], Batch [41/507], Loss: 0.0189
# Epoch [10/10], Batch [61/507], Loss: 0.0142
# Epoch [10/10], Batch [81/507], Loss: 0.0184
# Epoch [10/10], Batch [101/507], Loss: 0.0144
# Epoch [10/10], Batch [121/507], Loss: 0.0141
# Epoch [10/10], Batch [141/507], Loss: 0.0091
# Epoch [10/10], Batch [161/507], Loss: 0.0108
# Epoch [10/10], Batch [181/507], Loss: 0.0118
# Epoch [10/10], Batch [201/507], Loss: 0.0092
# Epoch [10/10], Batch [221/507], Loss: 0.0165
# Epoch [10/10], Batch [241/507], Loss: 0.0076
# Epoch [10/10], Batch [261/507], Loss: 0.0130
# Epoch [10/10], Batch [281/507], Loss: 0.0089
# Epoch [10/10], Batch [301/507], Loss: 0.0169
# Epoch [10/10], Batch [321/507], Loss: 0.0076
# Epoch [10/10], Batch [341/507], Loss: 0.0115
# Epoch [10/10], Batch [361/507], Loss: 0.0146
# Epoch [10/10], Batch [381/507], Loss: 0.0108
# Epoch [10/10], Batch [401/507], Loss: 0.0102
# Epoch [10/10], Batch [421/507], Loss: 0.0092
# Epoch [10/10], Batch [441/507], Loss: 0.0102
# Epoch [10/10], Batch [461/507], Loss: 0.0170
# Epoch [10/10], Batch [481/507], Loss: 0.0088
# Epoch [10/10], Batch [501/507], Loss: 0.0217
# Epoch [10/10], Loss: 0.0148
# Training completed.

# %%
torch.save(vgg16,"drive/MyDrive/LaneDetection/vgg16.pt")

# %%
class LaneRegressionLoss(nn.Module):
    def __init__(self):
        super(LaneRegressionLoss, self).__init__()
        self.regression_loss_fn = nn.MSELoss(reduction='none')  # Use 'none' to calculate loss per sample
        self.confidence_loss_fn = nn.BCEWithLogitsLoss()  # Applies a logistic loss to the confidence scores

    def forward(self, regression_pred, regression_target,confidence_target):
        # Regression loss where confidence is 1
        regression_pred = regression_pred.view(-1, 19, 17)
        regression_target = regression_target.view(-1, 19, 17)

        # Apply confidence target to each column of the regression output
        confidence_target_expanded = confidence_target.unsqueeze(1).expand_as(regression_pred)
        #print(confidence_target_expanded)
        regression_loss = self.regression_loss_fn(regression_pred, regression_target)  # Shape: [batch_size, 19, 17]
        regression_loss = (regression_loss * confidence_target_expanded).mean()


        return regression_loss

# %%
# torch.save(model,"drive/MyDrive/LaneDetection/LaneViT_confidence.pt") #This is only trained for confidence
# torch.save(model.state_dict(),"drive/MyDrive/LaneDetection/LaneViT_confidence_state_dict.pt") #Save the parameters also. Remember vgg16 parameters are seperately needed here

# %%
model = torch.load("drive/MyDrive/LaneDetection/LaneViT_confidence.pt")
# Out:
# <ipython-input-44-580f3650455b>:1: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model = torch.load("drive/MyDrive/LaneDetection/LaneViT_confidence.pt")

# %%
total_params = sum(p.numel() for p in model.parameters())
print(f"Number of parameters in million: {total_params/1000000}")
# Out:
# Number of parameters in million: 5.974732

# %%
import torch.optim as optim
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

model = model.to(device)
loss_fn = LaneRegressionLoss()
lane_dataset = LaneDataset(data_line_map=data_line_map,data_stline_map=data_stline_map,scale=(224,224))
dataloader = DataLoader(lane_dataset, batch_size=32,shuffle=True)
# Initialize the optimizer
optimizer = optim.Adam(model.parameters(), lr=0.001)
num_epochs = 10  # Adjust the number of epochs as needed

# %%
for param in model.vggblock.parameters():
            param.requires_grad = False #Disable the vgg trainings

for param in model.upsample_neck.parameters():
            param.requires_grad = False #Neck is already trained

for param in model.laneconfidence_head.parameters():
            param.requires_grad = False #Confidence is already trained

for param in model.regression_head.parameters():
            param.requires_grad = True #Now train only for regression head

# %%
import time

for epoch in range(num_epochs):
    model.train()  # Set the model to training mode
    running_loss = 0.0
    #print("Start",time.time())
    for batch_idx, (images, regression_targets, confidence_targets) in enumerate(dataloader):
        images = images.to(device)
        # max_lane_dis = max(max_lane_dis,regression_targets.max())
        # min_lane_dis = min(min_lane_dis,regression_targets.min())
        #print("Data fetched",time.time()
        regression_targets = regression_targets.to(device)
        confidence_targets = confidence_targets.to(device)
        #print("Datafetched",time.time())
        # Zero the parameter gradients
        optimizer.zero_grad()

        # Forward pass

        confidence_pred,regression_pred = model(images)

        # Calculate loss
        loss = loss_fn(regression_pred, regression_targets,confidence_targets)

        # Backward pass and optimize
        loss.backward()
        optimizer.step()

        # Update running loss
        running_loss += loss.item()

        # Print progress
        if batch_idx % 20 == 0:
            print(f'Epoch [{epoch+1}/{num_epochs}], Batch [{batch_idx+1}/{len(dataloader)}], Loss: {loss.item():.4f}')
            torch.save(model,"drive/MyDrive/LaneDetection/model_reg.pt")
        #print("Model stepped",time.time())
    # Print epoch loss
    print(f'Epoch [{epoch+1}/{num_epochs}], Loss: {running_loss/len(dataloader):.4f}')

print("Training completed.")
# Out:
# Epoch [1/10], Batch [1/507], Loss: 1359.3539
# Epoch [1/10], Batch [21/507], Loss: 239.0348
# Epoch [1/10], Batch [41/507], Loss: 19.5021
# Epoch [1/10], Batch [61/507], Loss: 12.9859
# Epoch [1/10], Batch [81/507], Loss: 11.0409
# Epoch [1/10], Batch [101/507], Loss: 1.7147
# Epoch [1/10], Batch [121/507], Loss: 3.1006
# Epoch [1/10], Batch [141/507], Loss: 2.5716
# Epoch [1/10], Batch [161/507], Loss: 2.5632
# Epoch [1/10], Batch [181/507], Loss: 2.0368
# Epoch [1/10], Batch [201/507], Loss: 11.5482
# Epoch [1/10], Batch [221/507], Loss: 6.9254
# Epoch [1/10], Batch [241/507], Loss: 5.4316
# Epoch [1/10], Batch [261/507], Loss: 2.9548
# Epoch [1/10], Batch [281/507], Loss: 3.5509
# Epoch [1/10], Batch [301/507], Loss: 2.7841
# Epoch [1/10], Batch [321/507], Loss: 1.9634
# Epoch [1/10], Batch [341/507], Loss: 3.4766
# Epoch [1/10], Batch [361/507], Loss: 95.3285
# Epoch [1/10], Batch [381/507], Loss: 4.4498
# Epoch [1/10], Batch [401/507], Loss: 5.2660
# Epoch [1/10], Batch [421/507], Loss: 5.7654
# Epoch [1/10], Batch [441/507], Loss: 2.7978
# Epoch [1/10], Batch [461/507], Loss: 6.1966
# Epoch [1/10], Batch [481/507], Loss: 2.4434
# Epoch [1/10], Batch [501/507], Loss: 2.3644
# Epoch [1/10], Loss: 49.3664
# Epoch [2/10], Batch [1/507], Loss: 2.4392
# Epoch [2/10], Batch [21/507], Loss: 2.3925
# Epoch [2/10], Batch [41/507], Loss: 2.4107
# Epoch [2/10], Batch [61/507], Loss: 3.4116
# Epoch [2/10], Batch [81/507], Loss: 3.2630
# Epoch [2/10], Batch [101/507], Loss: 5.3636
# Epoch [2/10], Batch [121/507], Loss: 3.6517
# Epoch [2/10], Batch [141/507], Loss: 3.4557
# Epoch [2/10], Batch [161/507], Loss: 2.7048
# Epoch [2/10], Batch [181/507], Loss: 2.9451
# Epoch [2/10], Batch [201/507], Loss: 2.4776
# Epoch [2/10], Batch [221/507], Loss: 3.6198
# Epoch [2/10], Batch [241/507], Loss: 2.7682
# Epoch [2/10], Batch [261/507], Loss: 2.5841
# Epoch [2/10], Batch [281/507], Loss: 6.2853
# Epoch [2/10], Batch [301/507], Loss: 4.9654
# Epoch [2/10], Batch [321/507], Loss: 3.9683
# Epoch [2/10], Batch [341/507], Loss: 11.0706
# Epoch [2/10], Batch [361/507], Loss: 2.9021
# Epoch [2/10], Batch [381/507], Loss: 6.0089
# Epoch [2/10], Batch [401/507], Loss: 2.7016
# Epoch [2/10], Batch [421/507], Loss: 5.7209
# Epoch [2/10], Batch [441/507], Loss: 5.7473
# Epoch [2/10], Batch [461/507], Loss: 8.7863
# Epoch [2/10], Batch [481/507], Loss: 5.5481
# Epoch [2/10], Batch [501/507], Loss: 3.2641
# Epoch [2/10], Loss: 4.3693
# Epoch [3/10], Batch [1/507], Loss: 2.8107
# Epoch [3/10], Batch [21/507], Loss: 3.1997
# Epoch [3/10], Batch [41/507], Loss: 2.4655
# Epoch [3/10], Batch [61/507], Loss: 6.6571
# Epoch [3/10], Batch [81/507], Loss: 13.6077
# Epoch [3/10], Batch [101/507], Loss: 2.6991
# Epoch [3/10], Batch [121/507], Loss: 4.9263
# Epoch [3/10], Batch [141/507], Loss: 3.8413
# Epoch [3/10], Batch [161/507], Loss: 2.8023
# Epoch [3/10], Batch [181/507], Loss: 5.3868
# Epoch [3/10], Batch [201/507], Loss: 4.5864
# Epoch [3/10], Batch [221/507], Loss: 12.6596
# Epoch [3/10], Batch [241/507], Loss: 7.1724
# Epoch [3/10], Batch [261/507], Loss: 5.9840
# Epoch [3/10], Batch [281/507], Loss: 3.0428
# Epoch [3/10], Batch [301/507], Loss: 10.2072
# Epoch [3/10], Batch [321/507], Loss: 4.0994
# Epoch [3/10], Batch [341/507], Loss: 4.5872
# Epoch [3/10], Batch [361/507], Loss: 4.3387
# Epoch [3/10], Batch [381/507], Loss: 4.9121
# Epoch [3/10], Batch [401/507], Loss: 2.6384
# Epoch [3/10], Batch [421/507], Loss: 5.5017
# Epoch [3/10], Batch [441/507], Loss: 2.6697
# Epoch [3/10], Batch [461/507], Loss: 2.6050
# Epoch [3/10], Batch [481/507], Loss: 4.5806
# Epoch [3/10], Batch [501/507], Loss: 1.9601
# Epoch [3/10], Loss: 4.4080
# Epoch [4/10], Batch [1/507], Loss: 6.6824
# Epoch [4/10], Batch [21/507], Loss: 2.8664
# Epoch [4/10], Batch [41/507], Loss: 2.8085
# Epoch [4/10], Batch [61/507], Loss: 3.0451
# Epoch [4/10], Batch [81/507], Loss: 4.4659
# Epoch [4/10], Batch [101/507], Loss: 3.8638
# Epoch [4/10], Batch [121/507], Loss: 4.6256
# Epoch [4/10], Batch [141/507], Loss: 2.8475
# Epoch [4/10], Batch [161/507], Loss: 3.0267
# Epoch [4/10], Batch [181/507], Loss: 3.0445
# Epoch [4/10], Batch [201/507], Loss: 3.2088
# Epoch [4/10], Batch [221/507], Loss: 5.9350
# Epoch [4/10], Batch [241/507], Loss: 7.0359
# Epoch [4/10], Batch [261/507], Loss: 4.8085
# Epoch [4/10], Batch [281/507], Loss: 8.1402
# Epoch [4/10], Batch [301/507], Loss: 3.0044
# Epoch [4/10], Batch [321/507], Loss: 3.2783
# Epoch [4/10], Batch [341/507], Loss: 2.6374
# Epoch [4/10], Batch [361/507], Loss: 2.8805
# Epoch [4/10], Batch [381/507], Loss: 5.2135
# Epoch [4/10], Batch [401/507], Loss: 6.4039
# Epoch [4/10], Batch [421/507], Loss: 2.9026
# Epoch [4/10], Batch [441/507], Loss: 2.5730
# Epoch [4/10], Batch [461/507], Loss: 2.1092
# Epoch [4/10], Batch [481/507], Loss: 5.4847
# Epoch [4/10], Batch [501/507], Loss: 10.2654
# Epoch [4/10], Loss: 4.4725
# Epoch [5/10], Batch [1/507], Loss: 3.0650
# Epoch [5/10], Batch [21/507], Loss: 5.2772
# Epoch [5/10], Batch [41/507], Loss: 7.5200
# Epoch [5/10], Batch [61/507], Loss: 2.4478
# Epoch [5/10], Batch [81/507], Loss: 14.8009
# Epoch [5/10], Batch [101/507], Loss: 2.0155
# Epoch [5/10], Batch [121/507], Loss: 4.5333
# Epoch [5/10], Batch [141/507], Loss: 3.4011
# Epoch [5/10], Batch [161/507], Loss: 3.7030
# Epoch [5/10], Batch [181/507], Loss: 5.4279
# Epoch [5/10], Batch [201/507], Loss: 2.2567
# Epoch [5/10], Batch [221/507], Loss: 3.3014
# Epoch [5/10], Batch [241/507], Loss: 18.1320
# Epoch [5/10], Batch [261/507], Loss: 4.2184
# Epoch [5/10], Batch [281/507], Loss: 8.7335
# Epoch [5/10], Batch [301/507], Loss: 3.9068
# Epoch [5/10], Batch [321/507], Loss: 2.5591
# Epoch [5/10], Batch [341/507], Loss: 3.1027
# Epoch [5/10], Batch [361/507], Loss: 4.8058
# Epoch [5/10], Batch [381/507], Loss: 2.9936
# Epoch [5/10], Batch [401/507], Loss: 3.5513
# Epoch [5/10], Batch [421/507], Loss: 4.1635
# Epoch [5/10], Batch [441/507], Loss: 7.2655
# Epoch [5/10], Batch [461/507], Loss: 3.4502
# Epoch [5/10], Batch [481/507], Loss: 4.3332
# Epoch [5/10], Batch [501/507], Loss: 2.8545
# Epoch [5/10], Loss: 4.5159
# Epoch [6/10], Batch [1/507], Loss: 3.0839
# Epoch [6/10], Batch [21/507], Loss: 6.6995
# Epoch [6/10], Batch [41/507], Loss: 3.3406
# Epoch [6/10], Batch [61/507], Loss: 2.7972
# Epoch [6/10], Batch [81/507], Loss: 3.1410
# Epoch [6/10], Batch [101/507], Loss: 3.0186
# Epoch [6/10], Batch [121/507], Loss: 8.5568
# Epoch [6/10], Batch [141/507], Loss: 3.2272
# Epoch [6/10], Batch [161/507], Loss: 2.4079
# Epoch [6/10], Batch [181/507], Loss: 2.3778
# Epoch [6/10], Batch [201/507], Loss: 2.1522
# Epoch [6/10], Batch [221/507], Loss: 4.5066
# Epoch [6/10], Batch [241/507], Loss: 3.4790
# Epoch [6/10], Batch [261/507], Loss: 4.1022
# Epoch [6/10], Batch [281/507], Loss: 3.8586
# Epoch [6/10], Batch [301/507], Loss: 3.2904
# Epoch [6/10], Batch [321/507], Loss: 3.5054
# Epoch [6/10], Batch [341/507], Loss: 3.4298
# Epoch [6/10], Batch [361/507], Loss: 4.0164
# Epoch [6/10], Batch [381/507], Loss: 5.7692
# Epoch [6/10], Batch [401/507], Loss: 2.6457
# Epoch [6/10], Batch [421/507], Loss: 3.6904
# Epoch [6/10], Batch [441/507], Loss: 2.8161
# Epoch [6/10], Batch [461/507], Loss: 7.2616
# Epoch [6/10], Batch [481/507], Loss: 3.0179
# Epoch [6/10], Batch [501/507], Loss: 6.9450
# Epoch [6/10], Loss: 4.4933
# Epoch [7/10], Batch [1/507], Loss: 3.4172
# Epoch [7/10], Batch [21/507], Loss: 31.3796
# Epoch [7/10], Batch [41/507], Loss: 3.3284
# Epoch [7/10], Batch [61/507], Loss: 6.9365
# Epoch [7/10], Batch [81/507], Loss: 2.3925
# Epoch [7/10], Batch [101/507], Loss: 3.4800
# Epoch [7/10], Batch [121/507], Loss: 4.7851
# Epoch [7/10], Batch [141/507], Loss: 3.0549
# Epoch [7/10], Batch [161/507], Loss: 2.3452
# Epoch [7/10], Batch [181/507], Loss: 4.4813
# Epoch [7/10], Batch [201/507], Loss: 2.8275
# Epoch [7/10], Batch [221/507], Loss: 20.9152
# Epoch [7/10], Batch [241/507], Loss: 3.3565
# Epoch [7/10], Batch [261/507], Loss: 3.7393
# Epoch [7/10], Batch [281/507], Loss: 2.5613
# Epoch [7/10], Batch [301/507], Loss: 3.7433
# Epoch [7/10], Batch [321/507], Loss: 4.4043
# Epoch [7/10], Batch [341/507], Loss: 3.9999
# Epoch [7/10], Batch [361/507], Loss: 4.2553
# Epoch [7/10], Batch [381/507], Loss: 2.5510
# Epoch [7/10], Batch [401/507], Loss: 2.7502
# Epoch [7/10], Batch [421/507], Loss: 3.9338
# Epoch [7/10], Batch [441/507], Loss: 3.9387
# Epoch [7/10], Batch [461/507], Loss: 7.3756
# Epoch [7/10], Batch [481/507], Loss: 3.6311
# Epoch [7/10], Batch [501/507], Loss: 3.1185
# Epoch [7/10], Loss: 4.4625
# Epoch [8/10], Batch [1/507], Loss: 2.4680
# Epoch [8/10], Batch [21/507], Loss: 2.8074
# Epoch [8/10], Batch [41/507], Loss: 3.0233
# Epoch [8/10], Batch [61/507], Loss: 2.0736
# Epoch [8/10], Batch [81/507], Loss: 4.4667
# Epoch [8/10], Batch [101/507], Loss: 7.2223
# Epoch [8/10], Batch [121/507], Loss: 3.6726
# Epoch [8/10], Batch [141/507], Loss: 2.4558
# Epoch [8/10], Batch [161/507], Loss: 2.7428
# Epoch [8/10], Batch [181/507], Loss: 6.6237
# Epoch [8/10], Batch [201/507], Loss: 3.3677
# Epoch [8/10], Batch [221/507], Loss: 4.8941
# Epoch [8/10], Batch [241/507], Loss: 2.7042
# Epoch [8/10], Batch [261/507], Loss: 3.3299
# Epoch [8/10], Batch [281/507], Loss: 2.6534
# Epoch [8/10], Batch [301/507], Loss: 6.7240
# Epoch [8/10], Batch [321/507], Loss: 7.6853
# Epoch [8/10], Batch [341/507], Loss: 3.0035
# Epoch [8/10], Batch [361/507], Loss: 2.8942
# Epoch [8/10], Batch [381/507], Loss: 4.3595
# Epoch [8/10], Batch [401/507], Loss: 3.6753
# Epoch [8/10], Batch [421/507], Loss: 2.4980
# Epoch [8/10], Batch [441/507], Loss: 5.4185
# Epoch [8/10], Batch [461/507], Loss: 3.1803
# Epoch [8/10], Batch [481/507], Loss: 3.0066
# Epoch [8/10], Batch [501/507], Loss: 2.7436
# Epoch [8/10], Loss: 4.4654
# Epoch [9/10], Batch [1/507], Loss: 2.5803
# Epoch [9/10], Batch [21/507], Loss: 3.4941
# Epoch [9/10], Batch [41/507], Loss: 7.6991
# Epoch [9/10], Batch [61/507], Loss: 1.9538
# Epoch [9/10], Batch [81/507], Loss: 3.0970
# Epoch [9/10], Batch [101/507], Loss: 4.8226
# Epoch [9/10], Batch [121/507], Loss: 4.4154
# Epoch [9/10], Batch [141/507], Loss: 2.6664
# Epoch [9/10], Batch [161/507], Loss: 2.6087
# Epoch [9/10], Batch [181/507], Loss: 3.2710
# Epoch [9/10], Batch [201/507], Loss: 2.2838
# Epoch [9/10], Batch [221/507], Loss: 3.3693
# Epoch [9/10], Batch [241/507], Loss: 6.4354
# Epoch [9/10], Batch [261/507], Loss: 2.8871
# Epoch [9/10], Batch [281/507], Loss: 7.4557
# Epoch [9/10], Batch [301/507], Loss: 6.8160
# Epoch [9/10], Batch [321/507], Loss: 5.1822
# Epoch [9/10], Batch [341/507], Loss: 2.2557
# Epoch [9/10], Batch [361/507], Loss: 2.0427
# Epoch [9/10], Batch [381/507], Loss: 6.7238
# Epoch [9/10], Batch [401/507], Loss: 7.9697
# Epoch [9/10], Batch [421/507], Loss: 4.5845
# Epoch [9/10], Batch [441/507], Loss: 4.8413
# Epoch [9/10], Batch [461/507], Loss: 5.6512
# Epoch [9/10], Batch [481/507], Loss: 8.4104
# Epoch [9/10], Batch [501/507], Loss: 3.2361
# Epoch [9/10], Loss: 4.4263
# Epoch [10/10], Batch [1/507], Loss: 5.0082
# Epoch [10/10], Batch [21/507], Loss: 6.0304
# Epoch [10/10], Batch [41/507], Loss: 2.9369
# Epoch [10/10], Batch [61/507], Loss: 7.0233
# Epoch [10/10], Batch [81/507], Loss: 5.4062
# Epoch [10/10], Batch [101/507], Loss: 3.4496
# Epoch [10/10], Batch [121/507], Loss: 4.1582
# Epoch [10/10], Batch [141/507], Loss: 2.3531
# Epoch [10/10], Batch [161/507], Loss: 3.3614
# Epoch [10/10], Batch [181/507], Loss: 4.1044
# Epoch [10/10], Batch [201/507], Loss: 2.9325
# Epoch [10/10], Batch [221/507], Loss: 3.6864
# Epoch [10/10], Batch [241/507], Loss: 4.1683
# Epoch [10/10], Batch [261/507], Loss: 3.1714
# Epoch [10/10], Batch [281/507], Loss: 5.5121
# Epoch [10/10], Batch [301/507], Loss: 2.3311
# Epoch [10/10], Batch [321/507], Loss: 2.2648
# Epoch [10/10], Batch [341/507], Loss: 2.9994
# Epoch [10/10], Batch [361/507], Loss: 2.5228
# Epoch [10/10], Batch [381/507], Loss: 2.9920
# Epoch [10/10], Batch [401/507], Loss: 3.1254
# Epoch [10/10], Batch [421/507], Loss: 4.5533
# Epoch [10/10], Batch [441/507], Loss: 4.3960
# Epoch [10/10], Batch [461/507], Loss: 3.1649
# Epoch [10/10], Batch [481/507], Loss: 3.5934
# Epoch [10/10], Batch [501/507], Loss: 4.1168
# Epoch [10/10], Loss: 4.4147
# Training completed.

# %%
#The model still shows signs of improvement. You can continue it when u have time.

# %%
# torch.save(model,"drive/MyDrive/LaneDetection/LaneViT_regression_2.pt") #This is only trained for confidence
# torch.save(model.state_dict(),"drive/MyDrive/LaneDetection/LaneViT_regression_state_dict_2.pt") #Save the parameters also. Remember vgg16 parameters are seperately needed here

# %% [markdown]
# #### Training all together : Experimental

# %%
class LaneLoss(nn.Module):
    def __init__(self):
        super(LaneLoss, self).__init__()
        self.regression_loss_fn = nn.MSELoss(reduction='none')  # Use 'none' to calculate loss per sample
        self.confidence_loss_fn = nn.BCEWithLogitsLoss()  # Applies a logistic loss to the confidence scores

    def forward(self, regression_pred, regression_target, confidence_pred, confidence_target):
        # Regression loss where confidence is 1
        regression_pred = regression_pred.view(-1, 19, 17)
        regression_target = regression_target.view(-1, 19, 17)

        #print(regression_pred.shape)

        # Apply confidence target to each column of the regression output
        confidence_target_expanded = confidence_target.unsqueeze(1).expand_as(regression_pred)
        #print(confidence_target_expanded)
        regression_loss = self.regression_loss_fn(regression_pred, regression_target)  # Shape: [batch_size, 19, 17]
        regression_loss = (regression_loss * confidence_target_expanded).mean()

        # Confidence loss (logistic loss)
        confidence_loss = self.confidence_loss_fn(confidence_pred, confidence_target)

        # Combine the losses
        total_loss = regression_loss/10 + confidence_loss #Dividing by 10 is experimental

        return total_loss

# %%
model = torch.load("drive/MyDrive/LaneDetection/LaneViT_regression.pt")

# %%
import torch.optim as optim
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

model = model.to(device)
loss_fn = LaneLoss()
lane_dataset = LaneDataset(data_line_map=data_line_map,data_stline_map=data_stline_map,scale=(224,224))
dataloader = DataLoader(lane_dataset, batch_size=32,shuffle=True)
# Initialize the optimizer
optimizer = optim.Adam(model.parameters(), lr=0.001)
num_epochs = 10  # Adjust the number of epochs as needed

# %%
for param in model.vggblock.parameters():
            param.requires_grad = False #Disable the vgg trainings

for param in model.upsample_neck.parameters():
            param.requires_grad = False #Neck is already trained

for param in model.laneconfidence_head.parameters():
            param.requires_grad = False #Confidence is already trained

for param in model.regression_head.parameters():
            param.requires_grad = True #Now train only for regression head

# %%
import time

for epoch in range(num_epochs):
    model.train()  # Set the model to training mode
    running_loss = 0.0
    #print("Start",time.time())
    for batch_idx, (images, regression_targets, confidence_targets) in enumerate(dataloader):
        images = images.to(device)
        # max_lane_dis = max(max_lane_dis,regression_targets.max())
        # min_lane_dis = min(min_lane_dis,regression_targets.min())
        #print("Data fetched",time.time()
        regression_targets = regression_targets.to(device)
        confidence_targets = confidence_targets.to(device)
        #print("Datafetched",time.time())
        # Zero the parameter gradients
        optimizer.zero_grad()

        # Forward pass

        confidence_pred,regression_pred = model(images)

        # Calculate loss
        loss = loss_fn(regression_pred, regression_targets,confidence_pred,confidence_targets)

        # Backward pass and optimize
        loss.backward()
        optimizer.step()

        # Update running loss
        running_loss += loss.item()

        # Print progress
        if batch_idx % 20 == 0:
            print(f'Epoch [{epoch+1}/{num_epochs}], Batch [{batch_idx+1}/{len(dataloader)}], Loss: {loss.item():.4f}')
            torch.save(model,"drive/MyDrive/LaneDetection/model_reg.pt")
        #print("Model stepped",time.time())
    # Print epoch loss
    print(f'Epoch [{epoch+1}/{num_epochs}], Loss: {running_loss/len(dataloader):.4f}')

print("Training completed.")
